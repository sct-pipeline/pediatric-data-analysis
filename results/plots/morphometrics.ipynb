# %% [markdown]
# # Morphometric analysis
#
# This notebook includes code to generate figures and statistical analyses for spinal cord morphometrics in pediatric subjects.

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
import plotly.graph_objects as go
from statsmodels.stats.multitest import multipletests
from plotly.subplots import make_subplots
import statsmodels.formula.api as smf
import re
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ## 1. Load files and prepare data for plotting

# %% [markdown]
# ### 1.1 Load config file to get path to dataset

# %%
# Load config file
with open('../../config/config_preprocessing.yaml' , 'r') as file:
    config = yaml.safe_load(file)

# Get data path from config file
path_data = config['path_data']

# %% [markdown]
# ### 1.2 Get the `participants.tsv` file from the dataset

# %%
# Get path to participants.tsv file
participants_tsv = pd.read_csv(os.path.join(path_data, 'participants.tsv'), sep='\t')
participants_tsv
# Out:
#     participant_id  age sex    group scan_series  height     weight  \
# 0          sub-101   17   M  control    complete  1.7780  68.038855
# 1          sub-102   15   F  control    complete  1.6256  52.163123
# 2          sub-103   15   M  control    complete  1.6510  54.431084
# 3          sub-104   16   F  control    complete  1.6256  52.163123
# 4          sub-105   13   M  control    complete  1.5494  35.380205
# ..             ...  ...  ..      ...         ...     ...        ...
# 131        sub-235   13   M  control  incomplete  1.7272  51.709530
# 132        sub-236   13   M  control    complete  1.6510  53.523900
# 133        sub-237   13   M  control    complete  1.6002  45.359237
# 134        sub-238   15   F  control    complete     NaN        NaN
# 135        sub-239    6   F  control    complete     NaN        NaN
#
#      height_for_age_percentile  weight_for_age_percentile  \
# 0                    63.322435                  61.657341
# ...

# %% [markdown]
# ### 1.3 Dataframe of subjects included in the pipeline analysis
#
# The following dataframe contains only the subjects that were included in this pipeline analysis.

# %%
def get_list_of_subjects_to_include(contrast, path_data, missing_data_subjects):
    """
    This function takes an image contrast (T2w, dwi, etc.), a path to a dataset, and a list of subjects with missing data,
    and returns a list of subjects to include in the analysis.

    The dataset needs to be in BIDS format, and the function will look for the participants.tsv file to get the list of subjects.
    The dataset should also contain an `exclude.yml` file that lists subjects to exclude from the analysis.
    """

    # Get the `participants.tsv` file and read it into a dataframe
    participants_tsv = pd.read_csv(os.path.join(path_data, 'participants.tsv'), sep='\t')

    # Get all subject IDs from the participants.tsv
    all_subjects = participants_tsv['participant_id'].tolist()

    # Get list of subjects to exclude from the analysis from the `exclude.yml` file
    with open(os.path.join(path_data, 'exclude.yml'), 'r') as file:
        exclude_yml = yaml.safe_load(file)

    exclude_t2star_key = exclude_yml.get(contrast, []) # Extract subjects under contrast key
    exclude_subjects = sorted(set(re.match(r"(sub-\d+)", entry).group(1) for entry in exclude_t2star_key if re.match(r"(sub-\d+)", entry))) # Extract the subject ID 

    # Add the list of subjects with missing data to the exclude_subjects list
    exclude_subjects.extend(missing_data_subjects)
    
    # Remove duplicates (if any), sort and print the list of subjects to exclude from the analysis
    exclude_subjects = sorted(set(exclude_subjects))
    print(f'subjects to exclude : {exclude_subjects}')

    # Compute the list of subjects to include in the analysis 
    include_subjects = [sub for sub in all_subjects if sub not in exclude_subjects]

    # Create a list of participants where the SC tip is visible (remove participants under the `sc-tip` flag in the `exclude.yml`)
    exclude_sc_tip_key = exclude_yml.get("sc-tip", []) # Extract subjects under the "sc-tip" key, corresponding to the list of participants where the sc tip is not visible on the T2w image
    exclude_sc_tip_subjects = sorted(set(re.match(r"(sub-\d+)", entry).group(1) for entry in exclude_sc_tip_key if re.match(r"(sub-\d+)", entry))) # Extract the subject ID 
    include_subjects_with_sc_tip = [sub for sub in include_subjects if sub not in exclude_sc_tip_subjects]

    # Convert the list of included subjects to dataframes
    include_subjects = participants_tsv[participants_tsv['participant_id'].isin(include_subjects)]
    include_subjects_with_sc_tip = participants_tsv[participants_tsv['participant_id'].isin(include_subjects_with_sc_tip)]


    return include_subjects, include_subjects_with_sc_tip

# %%
# List of subjects with missing rec-composed T2w data 
missing_t2_subjects = ["sub-217", 
                       "sub-218",
                       "sub-107",
                       "sub-125",
                       "sub-137",
                       "sub-144",
                       "sub-152",
                       "sub-221"]

# Get the list of subjects to include in the analysis
include_t2_subjects, include_subjects_with_sc_tip = get_list_of_subjects_to_include('t2w', path_data, missing_t2_subjects)
include_t2_subjects.to_csv(os.path.join('../tables/morphometrics/include_t2w_subjects.csv'), sep=',', index=False)
include_subjects_with_sc_tip .to_csv(os.path.join('../tables/morphometrics/include_t2w_subjects_with_sc_tip.csv'), sep=',', index=False)

print(include_t2_subjects.shape[0], "subjects to include in the T2w morphometric analysis\n")
print(f"\n list of subjects to include : \n {include_t2_subjects['participant_id'].tolist()}\n")

print(include_subjects_with_sc_tip .shape[0], "subjects with SC tip to include in the T2w morphometric analysis")
print(f"\n list of subjects with SC tip to include : \n {include_t2_subjects['participant_id'].tolist()}")
# Out:
# subjects to exclude : ['sub-107', 'sub-108', 'sub-110', 'sub-111', 'sub-121', 'sub-125', 'sub-133', 'sub-136', 'sub-137', 'sub-141', 'sub-144', 'sub-150', 'sub-152', 'sub-159', 'sub-160', 'sub-161', 'sub-163', 'sub-165', 'sub-167', 'sub-168', 'sub-169', 'sub-170', 'sub-177', 'sub-179', 'sub-186', 'sub-190', 'sub-191', 'sub-193', 'sub-198', 'sub-203', 'sub-208', 'sub-209', 'sub-211', 'sub-213', 'sub-214', 'sub-217', 'sub-218', 'sub-221', 'sub-236', 'sub-238']
# 96 subjects to include in the T2w morphometric analysis
#
#
#  list of subjects to include :
# ...

# %% [markdown]
# ### 1.4 Plot demographics
#
# This function plots the age and sex distribution of the subjects included in a pipeline analysis, according to the include list generated above.

# %%
def plot_demographics(df):
    """
    This function plots the demographic information of participants, given a dataframe with the list of subjects to include in the analysis.
    """

    # Sort by sex
    df_M = df[df['sex'] == 'M']
    df_F = df[df['sex'] == 'F']

    # Round down age to nearest month 
    df['age'] = np.floor(df['age']) 

    # Create subplot
    fig = make_subplots(rows=1, cols=1)

    # Add histogram for female subjects
    fig.add_trace(go.Histogram(
        x=df_F['age'], 
        name='F', 
        marker=dict(color= "#D19D88"),
        opacity=1.0,
        legendgroup='F',
        ),
        row=1, col=1
    )

    # Add histogram for male subjects
    fig.add_trace(go.Histogram(
        x=df_M['age'], 
        name='M', 
        
        marker=dict(color="#5C8EA1"),
        opacity=1.0,
        legendgroup='M',
        ), 
        row=1, col=1
    )

    # Define age tick range
    tick_vals = list(range(6, 18)) 

    # Update layout
    fig.update_layout(
        width=900,
        height=500,
        font=dict(family='Arial', size=20, color='black'), 
        legend=dict(
            orientation="h", 
            yanchor="bottom", 
            y=1.0, 
            xanchor="center",  
            x=0.5,
        ),
        xaxis=dict(
            range=[5, 18],  # Set x-axis range from 6 to 17
        ),
        plot_bgcolor='white',
        barmode='stack',
        bargap=0.3,  
        xaxis_title='Age (years)',
        xaxis_title_font=dict(family='Arial', size=20, weight='bold'),
        yaxis_title='Number of Subjects',
        yaxis_title_font=dict(family='Arial', size=20, weight='bold'),
        xaxis_title_standoff=50, 
    )

    fig.update_xaxes(
        tickmode='array',
        tickvals=tick_vals,
        showgrid=False,
        gridwidth=1
    )

    fig.update_yaxes(
        showgrid=True,             # Horizontal grid lines
        gridcolor='lightgrey',
        gridwidth=1
    )

    # Set bin size to 1 year
    fig.update_traces(xbins=dict(size=1))

    fig.show()

# %%
# Plot demographics for included subjects in T2w analysis
plot_demographics(include_t2_subjects)

# %% [markdown]
# ### 1.5 Create dataframe containing interpolated morphometrics
# Load the CSV files containing interpolated morphometrics (ending with `_interpolated_morphometrics.csv`) and create a single dataframe containing all participants

# %%
# Path to morphometric
morphometric_results_dir = '../tables/morphometrics/'

# Path to participants.tsv
participants_info_path = os.path.join(path_data, 'participants.tsv')

# Initialize an empty DataFrame to store morphometric values
interpolated_morphometrics_df = pd.DataFrame()

# Load the CSV files containing morphometric values of each subject and add to a single dataframe
for file in os.listdir(morphometric_results_dir):
    if file.endswith('_interpolated_morphometrics.csv'):
        df = pd.read_csv(os.path.join(morphometric_results_dir, file))
        interpolated_morphometrics_df = pd.concat([interpolated_morphometrics_df, df], ignore_index=True)

# Keep only subjects included in the include_t2_subjects list 
interpolated_morphometrics_df = interpolated_morphometrics_df[interpolated_morphometrics_df["subject"].isin(include_t2_subjects["participant_id"])].reset_index(drop=True)

# Remove the last point (spinal cord tip) for each subject
idx = interpolated_morphometrics_df.groupby("subject")["VertLevel"].idxmax()
interpolated_morphometrics_df = interpolated_morphometrics_df.drop(idx).reset_index(drop=True)

# Remove age and sex columns if they exist
if 'age' in interpolated_morphometrics_df.columns:
    interpolated_morphometrics_df = interpolated_morphometrics_df.drop(columns=['age'])
if 'sex' in interpolated_morphometrics_df.columns:
    interpolated_morphometrics_df = interpolated_morphometrics_df.drop(columns=['sex'])

# %%
# Add sex and age columns to the DataFrame (using participants.tsv)
participants_info = pd.read_csv(participants_info_path, sep='\t')
participants_info = participants_info.rename(columns={'participant_id': 'subject'})

participants_info = participants_info[['subject', 'age', 'sex']]
interpolated_morphometrics_df = interpolated_morphometrics_df.merge(participants_info, on='subject', how='left')

print("Number of subjects:", interpolated_morphometrics_df["subject"].nunique())
print(interpolated_morphometrics_df["subject"].unique())
# Out:
# Number of subjects: 94
# ['sub-232' 'sub-102' 'sub-234' 'sub-227' 'sub-117' 'sub-158' 'sub-104'
#  'sub-147' 'sub-154' 'sub-182' 'sub-205' 'sub-216' 'sub-126' 'sub-135'
#  'sub-197' 'sub-210' 'sub-184' 'sub-120' 'sub-176' 'sub-139' 'sub-188'
#  'sub-226' 'sub-235' 'sub-105' 'sub-116' 'sub-233' 'sub-220' 'sub-103'
#  'sub-155' 'sub-109' 'sub-146' 'sub-239' 'sub-140' 'sub-153' 'sub-185'
#  'sub-202' 'sub-196' 'sub-132' 'sub-204' 'sub-183' 'sub-134' 'sub-127'
#  'sub-171' 'sub-162' 'sub-189' 'sub-164' 'sub-138' 'sub-143' 'sub-229'
#  'sub-119' 'sub-156' 'sub-113' 'sub-230' 'sub-223' 'sub-149' 'sub-106'
#  'sub-115' 'sub-225' 'sub-128' 'sub-174' 'sub-199' 'sub-172' 'sub-178'
#  'sub-124' 'sub-180' 'sub-207' 'sub-122' 'sub-131' 'sub-201' 'sub-212'
#  'sub-228' 'sub-118' 'sub-142' 'sub-114' 'sub-148' 'sub-237' 'sub-224'
#  'sub-101' 'sub-112' 'sub-222' 'sub-231' 'sub-173' 'sub-219' 'sub-175'
#  'sub-166' 'sub-129' 'sub-130' 'sub-123' 'sub-194' 'sub-200' 'sub-206'
# ...

# %%
interpolated_morphometrics_df
# Out:
#        subject  VertLevel  DistancePMJ        CSA  AP_diameter  RL_diameter  \
# 0      sub-232        1.0    26.750000  61.858208     8.043682     9.728889
# 1      sub-232        1.1    28.354000  59.698281     7.788287     9.721150
# 2      sub-232        1.2    29.958000  57.825237     7.534657     9.747406
# 3      sub-232        1.3    31.562000  57.367667     7.469191     9.773150
# 4      sub-232        1.4    33.166000  57.215116     7.385822     9.867722
# ...        ...        ...          ...        ...          ...          ...
# 18260  sub-215       19.8   389.712000   9.206335     3.219219     3.500992
# 18261  sub-215       19.9   392.471000   7.420212     2.616683     3.363068
# 18262  sub-215       20.0   395.230000   8.559618     3.175002     3.272243
# 18263  sub-215       20.1   398.164869   5.440488     2.494596     2.560332
# 18264  sub-215       20.2   401.099739   2.323164     1.418506     1.340934
#
# ...

# %% [markdown]
# ### 1.6 Create dataframe containing per-slice morphometrics
# Load the CSV files containing per-slice morphometrics (ending with `_per_slice.csv`) and create a single dataframe containing all participants

# %%
# Initialize an empty DataFrame to store per slice morphometric values
per_slice_df = pd.DataFrame()

# Load the CSV files containing morphometric values of each subject and add to a single dataframe
for file in os.listdir(morphometric_results_dir):
    if file.endswith('_per_slice.csv'):
        df = pd.read_csv(os.path.join(morphometric_results_dir, file))
        df = df.dropna(subset=["MEAN(area)"]) # remove rows where the CSA is NaN
        per_slice_df = pd.concat([per_slice_df, df], ignore_index=True)

# Add subject column from the 'Filename' column
for index, row in per_slice_df.iterrows():
    filename = row['Filename']
    filename = Path(filename)
    
    # Subject folder is the parent directory before "anat"
    subject_id = filename.parts[-3]

    # Add to the dataframe
    per_slice_df.loc[index, 'subject'] = subject_id

# Keep only subjects included in the include_t2_subjects list 
per_slice_df = per_slice_df[per_slice_df["subject"].isin(include_subjects_with_sc_tip["participant_id"])].reset_index(drop=True)

print("Number of subjects:", per_slice_df["subject"].nunique())

# Add sex and age columns to the DataFrame (using participants.tsv)
participants_info = pd.read_csv(participants_info_path, sep='\t')
participants_info = participants_info.rename(columns={'participant_id': 'subject'})

participants_info = participants_info[['subject', 'age', 'sex']]
per_slice_df = per_slice_df.merge(participants_info, on='subject', how='left')
# Out:
# Number of subjects: 79

# %%
per_slice_df
# Out:
#                  Timestamp  SCT Version  \
# 0      2026-07-02 19:52:53          7.1
# 1      2026-07-02 19:52:53          7.1
# 2      2026-07-02 19:52:53          7.1
# 3      2026-07-02 19:52:53          7.1
# 4      2026-07-02 19:52:53          7.1
# ...                    ...          ...
# 36043  2026-07-03 00:23:43          7.1
# 36044  2026-07-03 00:23:43          7.1
# 36045  2026-07-03 00:23:43          7.1
# 36046  2026-07-03 00:23:43          7.1
# 36047  2026-07-03 00:23:43          7.1
#
#                                                 Filename  Slice (I->S)  \
# 0      /Users/samuellestonge/Documents/datasets/phila...            31
# 1      /Users/samuellestonge/Documents/datasets/phila...            32
# 2      /Users/samuellestonge/Documents/datasets/phila...            33
# 3      /Users/samuellestonge/Documents/datasets/phila...            34
# 4      /Users/samuellestonge/Documents/datasets/phila...            35
# ...

# %% [markdown]
# ### 1.7 Create dataframe containing per-vertebral level morphometrics
# Load the CSV files containing per-slice morphometrics (ending with `_per_vertlevel.csv`) and create a single dataframe containing all participants

# %%
# Initialize an empty DataFrame to store per slice morphometric values
per_vertlevel_df = pd.DataFrame()

# Load the CSV files containing morphometric values of each subject and add to a single dataframe
for file in os.listdir(morphometric_results_dir):
    if file.endswith('_per_vertlevel.csv'):
        df = pd.read_csv(os.path.join(morphometric_results_dir, file))
        df = df.dropna(subset=["MEAN(area)"]) # remove rows where the CSA is NaN
        per_vertlevel_df = pd.concat([per_vertlevel_df, df], ignore_index=True)

# Add subject column from the 'Filename' column
for index, row in per_vertlevel_df.iterrows():
    filename = row['Filename']
    filename = Path(filename)
    
    # Subject folder is the parent directory before "anat"
    subject_id = filename.parts[-3]

    # Add to the dataframe
    per_vertlevel_df.loc[index, 'subject'] = subject_id

# Keep only subjects included in the include_t2_subjects list 
per_vertlevel_df = per_vertlevel_df[per_vertlevel_df["subject"].isin(include_t2_subjects["participant_id"])].reset_index(drop=True)

# Rename columns 
per_vertlevel_df = per_vertlevel_df.rename(columns={'MEAN(area)': 'CSA'})

print("Number of subjects:", per_vertlevel_df["subject"].nunique())

# Add subject, age, sex, and height/weight percentiles to the DataFrame (using participants.tsv)
participants_info = pd.read_csv(participants_info_path, sep='\t')
participants_info = participants_info.rename(columns={'participant_id': 'subject'})

participants_info = participants_info[['subject', 'age', 'sex', 'height', 'weight', 'height_for_age_percentile', 'weight_for_age_percentile', 'height_for_age_zscore', 'weight_for_age_zscore']]
per_vertlevel_df = per_vertlevel_df.merge(participants_info, on='subject', how='left')
# Out:
# Number of subjects: 94

# %%
per_vertlevel_df
# Out:
#                 Timestamp  SCT Version  \
# 0     2026-07-24 15:27:36          7.1
# 1     2026-07-24 15:27:36          7.1
# 2     2026-07-24 15:27:36          7.1
# 3     2026-07-24 15:27:36          7.1
# 4     2026-07-24 15:27:36          7.1
# ...                   ...          ...
# 1861  2026-07-24 15:28:28          7.1
# 1862  2026-07-24 15:28:28          7.1
# 1863  2026-07-24 15:28:28          7.1
# 1864  2026-07-24 15:28:28          7.1
# 1865  2026-07-24 15:28:28          7.1
#
#                                                Filename Slice (I->S)  \
# 0     /Users/samuellestonge/Documents/datasets/phila...      120:123
# 1     /Users/samuellestonge/Documents/datasets/phila...      124:152
# 2     /Users/samuellestonge/Documents/datasets/phila...      153:183
# 3     /Users/samuellestonge/Documents/datasets/phila...      184:207
# 4     /Users/samuellestonge/Documents/datasets/phila...      208:227
# ...                                                 ...          ...
# ...

# %% [markdown]
# ### 2. Plotting functions

# %% [markdown]
# #### 2.1 Function to plot morphometrics per vertebral levels

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import webbrowser

def plot_morphometrics(df, morphometric_name_in_csv, morphometric_display_name, sex=None):

    # Assign a color to each age in the dataframe
    unique_ages = sorted(df['age'].unique())

    # Count the number of participants per age (for legend)
    age_counts = df.groupby('age')['subject'].nunique().to_dict()

    # Get 12 evenly spaced colors from a colormap
    colorscale = px.colors.diverging.Portland
    num_colors = 12
    color_gradient = px.colors.sample_colorscale(colorscale, [i / (num_colors - 1) for i in range(num_colors)])

    # Sort the ages and assign a color from the gradient
    color_map = {age: color_gradient[i] for i, age in enumerate(unique_ages)}
                 
    # Filter by sex (optional)
    if sex is not None:
        if 'sex' not in df.columns:
            raise ValueError("Column 'sex' not found in dataframe.")
        df = df[df['sex'] == sex].copy()

    # Initialize figure
    fig = go.Figure()

    # Plot one line per subject
    for subject, sub_df in df.groupby('subject'):

        sub_df = sub_df.sort_values('VertLevel')

        age = sub_df['age'].iloc[0]
        color = color_map[age]

        fig.add_trace(go.Scatter(
            x=sub_df['VertLevel'],
            y=sub_df[morphometric_name_in_csv],
            mode='lines',
            line=dict(color=color, width=1),
            opacity=0.7,
            name=str(age),
            legendgroup=str(age),
            showlegend=False
        ))

    for age in unique_ages:
        fig.add_trace(go.Scatter(
            x=[None],
            y=[None],
            mode='lines',
            line=dict(color=color_map[age], width=2),
            name=f"{age}  (N={age_counts[age]})",
            showlegend=True
        ))

    # Layout
    fig.update_layout(
        width=1000,
        height=600,
        title=f" ",
        xaxis_title='Vertebral Level',
        xaxis_title_font=dict(size=20, color='black', family='Arial', weight='bold'),
        yaxis_title=morphometric_display_name,
        yaxis_title_font=dict(size=20, color='black', family='Arial', weight='bold'),
        legend_title='Age (years)<br>',
        legend_title_font=dict(size=14, color='black', family='Arial', weight='bold'),
        legend_font=dict(size=12, color='black', family='Arial'),
        xaxis_tickangle=-45,
        template='plotly_white',
    )
    
    # Map VertLevel numbers to anatomical labels
    vertebral_label_map = {
        0.0: "PMJ", 1.0: "Tip of C1", 2.0: "C1-C2", 3.0: "C2-C3", 4.0: "C3-C4", 
        5.0: "C4-C5", 6.0: "C5-C6", 7.0: "C6-C7", 8.0: "C7-T1", 9.0: "T1-T2", 
        10.0: "T2-T3", 11.0: "T3-T4", 12.0: "T4-T5", 13.0: "T5-T6", 14.0: "T6-T7", 
        15.0: "T7-T8", 16.0: "T8-T9", 17.0: "T9-T10", 18.0: "T10-T11", 19.0: "T11-T12", 
        20.0: "T12-L1", 21.0: "L1-L2", 22.0: "L2-L3", 23.0: "L3-L4"
    }

    # Extract all vertebral levels used in the data
    all_vert_levels = sorted(df['VertLevel'].dropna().unique())

    # Filter only integer levels (to show only C1, C2, etc.)
    integer_vert_levels = [v for v in all_vert_levels if v.is_integer() and v in vertebral_label_map]

    # Map to anatomical labels
    ticktexts = [vertebral_label_map[v] for v in integer_vert_levels]

    # Update the x-axis to show anatomical vertebral labels
    fig.update_xaxes(
        tickmode='array',
        tickvals=integer_vert_levels,
        ticktext=ticktexts,
        tickcolor='black',
        tickfont=dict(size=16, color='black', family='Arial'),
        tickangle=270,
        gridcolor='rgba(0, 0, 0, 0.1)',  
        
    )
    
    fig.update_yaxes(
        gridcolor='rgba(0, 0, 0, 0.1)',
        tickcolor='black',
        tickfont=dict(size=16, color='black', family='Arial')
    )

    # Define the save path
    save_path = os.path.join('..', 'figures', f'{morphometric_name_in_csv}_vs_Vert_Levels.html')

    # Save the figure to an HTML file
    fig.write_html(save_path)

    # Open the file in the default web browser
    # webbrowser.open(f'file://{os.path.abspath(save_path)}')

    # Show the figure in the notebook as well
    fig.show()

# %% [markdown]
# #### 2.2 Function to plot the average morphometrics for each age, per vertebral level

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import webbrowser

def plot_average_morphometrics(df, morphometric_name_in_csv, morphometric_display_name, sex=None):

    """
    This function plots the average morphometrics per age (each curve represents the average of an age between 6 and 17)
    """

    # Assign a color to each age in the dataframe
    unique_ages = sorted(df['age'].unique())

    # Count the number of participants per age (for legend)
    age_counts = df.groupby('age')['subject'].nunique().to_dict()

    # Get 12 evenly spaced colors from a colormap
    colorscale = px.colors.diverging.Portland
    num_colors = 12
    color_gradient = px.colors.sample_colorscale(colorscale, [i / (num_colors - 1) for i in range(num_colors)])

    # Sort the ages and assign a color from the gradient
    color_map = {age: color_gradient[i] for i, age in enumerate(unique_ages)}
                 
    # Filter by sex (optional)
    if sex is not None:
        if 'sex' not in df.columns:
            raise ValueError("Column 'sex' not found in dataframe.")
        df = df[df['sex'] == sex].copy()

    # Compute mean and std dev per age and vertebral level
    grouped = df.groupby(['age', 'VertLevel'])[morphometric_name_in_csv].agg(['mean', 'std']).reset_index()

    # Initialize figure
    fig = go.Figure()

    # Plot each age group
    for age in unique_ages:
        group = grouped[grouped['age'] == age].sort_values('VertLevel')

        x = group['VertLevel']
        y_mean = group['mean']
        y_std = group['std']

        y_upper = y_mean + y_std
        y_lower = y_mean - y_std
        color = color_map[age]

        # Add mean line
        fig.add_trace(go.Scatter(
            x=x,
            y=y_mean,
            mode='lines',
            name=f"{age}  (N={age_counts[age]})",
            line=dict(color=color, width=2),
            marker=dict(size=6),
            legendgroup=f'Age {age}'
        ))

    # Layout
    fig.update_layout(
        width=1000,
        height=600,
        title=f" ",
        xaxis_title='Vertebral Level',
        xaxis_title_font=dict(size=20, color='black', family='Arial', weight='bold'),
        yaxis_title=morphometric_display_name,
        yaxis_title_font=dict(size=20, color='black', family='Arial', weight='bold'),
        legend_title='Age (years)<br>',
        legend_title_font=dict(size=14, color='black', family='Arial', weight='bold'),
        legend_font=dict(size=12, color='black', family='Arial'),
        xaxis_tickangle=-45,
        template='plotly_white',
    )
    
    # Map VertLevel numbers to anatomical labels
    vertebral_label_map = {
        0.0: "PMJ", 1.0: "Tip of C1", 2.0: "C1-C2", 3.0: "C2-C3", 4.0: "C3-C4", 
        5.0: "C4-C5", 6.0: "C5-C6", 7.0: "C6-C7", 8.0: "C7-T1", 9.0: "T1-T2", 
        10.0: "T2-T3", 11.0: "T3-T4", 12.0: "T4-T5", 13.0: "T5-T6", 14.0: "T6-T7", 
        15.0: "T7-T8", 16.0: "T8-T9", 17.0: "T9-T10", 18.0: "T10-T11", 19.0: "T11-T12", 
        20.0: "T12-L1", 21.0: "L1-L2", 22.0: "L2-L3", 23.0: "L3-L4"
    }

    # Extract all vertebral levels used in the data
    all_vert_levels = sorted(df['VertLevel'].dropna().unique())

    # Filter only integer levels (to show only C1, C2, etc.)
    integer_vert_levels = [v for v in all_vert_levels if v.is_integer() and v in vertebral_label_map]

    # Map to anatomical labels
    ticktexts = [vertebral_label_map[v] for v in integer_vert_levels]

    # Update the x-axis to show anatomical vertebral labels
    fig.update_xaxes(
        tickmode='array',
        tickvals=integer_vert_levels,
        ticktext=ticktexts,
        tickcolor='black',
        tickfont=dict(size=16, color='black', family='Arial'),
        tickangle=270,
        gridcolor='rgba(0, 0, 0, 0.1)',  
        
    )
    
    fig.update_yaxes(
        gridcolor='rgba(0, 0, 0, 0.1)',
        tickcolor='black',
        tickfont=dict(size=16, color='black', family='Arial')
    )

    # Define the save path
    save_path = os.path.join('..', 'figures', f'{morphometric_name_in_csv}_vs_Vert_Levels.html')

    # Save the figure to an HTML file
    fig.write_html(save_path)

    # Open the file in the default web browser
    # webbrowser.open(f'file://{os.path.abspath(save_path)}')

    # Show the figure in the notebook as well
    fig.show()

# %% [markdown]
# ### 2.3 Function to plot morphometrics per spinal cord landmarks (PMJ + spinal cord tip)

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import webbrowser
import os

def plot_morphometrics_SC_landmarks(df, SC_landmark_normalization, morphometric_name_in_csv, morphometric_display_name):

    fig = go.Figure()

    # Get unique subjects
    unique_subjects = sorted(df["subject"].unique())

    # Get unique ages
    unique_ages = sorted(df["age"].unique())

    # 12 colors from the Portland colorscale
    colorscale = px.colors.diverging.Portland
    num_colors = 12
    color_gradient = px.colors.sample_colorscale(
        colorscale,
        [i / (num_colors - 1) for i in range(num_colors)]
    )

    # Assign one of the 12 colors to each age
    color_map = {
        age: color_gradient[i % num_colors]
        for i, age in enumerate(unique_ages)
    }

    # Loop over subjects
    for subject in unique_subjects:

        subject_df = df[df["subject"] == subject]

        age = subject_df["age"].iloc[0]

        x = subject_df[SC_landmark_normalization]
        y = subject_df[morphometric_name_in_csv]

        fig.add_trace(go.Scatter(
            x=x,
            y=y,
            mode="lines",
            name=subject,
            line=dict(color=color_map[age], width=1),
            opacity=0.8,
        ))

    # Layout
    fig.update_layout(
        width=1000,
        height=600,
        xaxis_title='PMJ to SC tip',
        yaxis_title=morphometric_display_name,
        template='plotly_white',
        legend_title='Subjects'
    )

    # # Save figure in HTML format : 
    # save_path = os.path.join('..', 'figures',
    #                          f'{morphometric_name_in_csv}_vs_Vert_Levels.html')
    # fig.write_html(save_path)
    # webbrowser.open(f'file://{os.path.abspath(save_path)}')
    
    # Show figure in notebook : 
    fig.show()

# %% [markdown]
# ### 2.3 Function that interpolates each subject's curve onto a common grid (0 to 1)
#
# This is because, in the per_slice.csv files, not every participant has the same number of values interpolated between 0 and 1 (from the PMJ to the SC tip). To simplify the analyses, we created a function to interpolate 200 points between 0 to 1, so that each participant will have the same number of points to trace the curve. This number of points will correspond to number of maximum number of slices between the PMJ and the SC tip across all participants.

# %%
import numpy as np
import pandas as pd

def interpolate_curves(df, subject_col, pos_col, csa_col):
    """
    Interpolates each subject's curve onto a common grid (0 to 1) with the same number of points. 

    Parameters
    ----------
    df : pandas.DataFrame
        Input dataframe with subject, position, and CSA columns
    subject_col : str
        Column name for subject IDs
    pos_col : str
        Column name for normalized positions (values between 0 and 1)
    csa_col : str
        Column name for CSA values
    n_points : int
        Number of points in the interpolated grid (default: 200)

    Returns
    -------
    df_interp : pandas.DataFrame
        DataFrame in long format with columns:
        [subject_col, pos_col, csa_col]
        where pos_col now has n_points equally spaced values from 0 to 1 per subject
    """

    subjects = df[subject_col].unique() # Get the list of subjects

    # Step 1 : Get the number of points (corresponding to the maximum number of slices between the PMJ and the SC across the dataset)

    for subj in subjects:
        # Get the subset of the dataset corresponding to that subject
        subj_df = df[df[subject_col] == subj]
        # Get number of values (points) for that subject in the "pos_col" column 
        n_points = subj_df[pos_col].notna().sum()


    # Step 2 : Define a common normalized grid between 0 and 1, with n_points as the number of points,
    # so every subject’s curve can be interpolated onto the same positions on the x axis
    x_common = np.linspace(0, 1, n_points)
    data_list = []


    # Step 3 : Resample each subject's CSA values onto the common normalized grid, so that each subject
    # has the same number of points, in the same x position (between 0 and 1)

    for subj in subjects:
        sub = df[df[subject_col] == subj].sort_values(pos_col)
        x = sub[pos_col].values
        y = sub[csa_col].values

        # Interpolate onto common grid
        y_interp = np.interp(x_common, x, y)

        # Keep only the region where the subject originally had data
        y_interp[(x_common < x.min()) | (x_common > x.max())] = np.nan

        # Repeat the first row (which contains the subject metadata)
        df_subj = pd.concat([sub.iloc[[0]]] * len(x_common), ignore_index=True)

        # Replace the interpolated columns
        df_subj[pos_col] = x_common
        df_subj[csa_col] = y_interp

        data_list.append(df_subj)

    df_interp = pd.concat(data_list, ignore_index=True)
    
    return df_interp

# %% [markdown]
# ### 2.4 Function that computes the average curve and plots the difference between each participant's CSA curve and the average curve

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import webbrowser

def plot_difference_CSA_population_mean(df, morphometric_name_in_csv, morphometric_display_name):

    # Assign a color to each age in the dataframe
    unique_ages = sorted(df['age'].unique())

    # Count the number of participants per age (for legend)
    age_counts = df.groupby('age')['subject'].nunique().to_dict()

    # Get 12 evenly spaced colors from a colormap
    colorscale = px.colors.diverging.Portland
    num_colors = 12
    color_gradient = px.colors.sample_colorscale(colorscale, [i / (num_colors - 1) for i in range(num_colors)])

    # Sort the ages and assign a color from the gradient
    color_map = {age: color_gradient[i] for i, age in enumerate(unique_ages)}

    # Compute the mean CSA profile across all participants
    mean_profile = (
        df.groupby("VertLevel")[morphometric_name_in_csv]
        .mean()
        .rename("MeanValue")
    )

    # Add the mean value to every row
    df = df.merge(mean_profile, on="VertLevel")

    # Compute the difference of each participant's CSA curve from the population mean
    df["Difference"] = (df[morphometric_name_in_csv] - df["MeanValue"])

    # Initialize figure
    fig = go.Figure()

    # Plot one line per subject
    for subject, sub_df in df.groupby('subject'):

        sub_df = sub_df.sort_values('VertLevel')

        age = sub_df['age'].iloc[0]
        color = color_map[age]

        fig.add_trace(go.Scatter(
            x=sub_df['VertLevel'],
            y=sub_df["Difference"],
            mode='lines',
            line=dict(color=color, width=1),
            opacity=0.7,
            name=str(age),
            legendgroup=str(age),
            showlegend=False
        ))

    for age in unique_ages:
        fig.add_trace(go.Scatter(
            x=[None],
            y=[None],
            mode='lines',
            line=dict(color=color_map[age], width=2),
            name=f"{age}  (N={age_counts[age]})",
            showlegend=True
        ))

    # Layout
    fig.update_layout(
        width=1000,
        height=600,
        title=f" ",
        xaxis_title='Vertebral Level',
        xaxis_title_font=dict(size=20, color='black', family='Arial', weight='bold'),
        yaxis_title=f"{morphometric_display_name} − Mean",
        legend_title='Age (years)<br>',
        legend_title_font=dict(size=14, color='black', family='Arial', weight='bold'),
        legend_font=dict(size=12, color='black', family='Arial'),
        xaxis_tickangle=-45,
        template='plotly_white',
    )

    # Add reference line
    fig.add_hline(
    y=0,
    line_dash="dash",
    line_color="black",
    line_width=2
    )
    
    # Map VertLevel numbers to anatomical labels
    vertebral_label_map = {
        0.0: "PMJ", 1.0: "Tip of C1", 2.0: "C1-C2", 3.0: "C2-C3", 4.0: "C3-C4", 
        5.0: "C4-C5", 6.0: "C5-C6", 7.0: "C6-C7", 8.0: "C7-T1", 9.0: "T1-T2", 
        10.0: "T2-T3", 11.0: "T3-T4", 12.0: "T4-T5", 13.0: "T5-T6", 14.0: "T6-T7", 
        15.0: "T7-T8", 16.0: "T8-T9", 17.0: "T9-T10", 18.0: "T10-T11", 19.0: "T11-T12", 
        20.0: "T12-L1", 21.0: "L1-L2", 22.0: "L2-L3", 23.0: "L3-L4"
    }

    # Extract all vertebral levels used in the data
    all_vert_levels = sorted(df['VertLevel'].dropna().unique())

    # Filter only integer levels (to show only C1, C2, etc.)
    integer_vert_levels = [v for v in all_vert_levels if v.is_integer() and v in vertebral_label_map]

    # Map to anatomical labels
    ticktexts = [vertebral_label_map[v] for v in integer_vert_levels]

    # Update the x-axis to show anatomical vertebral labels
    fig.update_xaxes(
        tickmode='array',
        tickvals=integer_vert_levels,
        ticktext=ticktexts,
        tickcolor='black',
        tickfont=dict(size=16, color='black', family='Arial'),
        tickangle=270,
        gridcolor='rgba(0, 0, 0, 0.1)',  
        
    )
    
    fig.update_yaxes(
        gridcolor='rgba(0, 0, 0, 0.1)',
        tickcolor='black',
        tickfont=dict(size=16, color='black', family='Arial')
    )

    # Define the save path
    save_path = os.path.join('..', 'figures', f'{morphometric_name_in_csv}_vs_Vert_Levels.html')

    # Save the figure to an HTML file
    fig.write_html(save_path)

    # Open the file in the default web browser
    # webbrowser.open(f'file://{os.path.abspath(save_path)}')

    # Show the figure in the notebook as well
    fig.show()

# %% [markdown]
# ### 3. Plots

# %% [markdown]
# #### 3.1 Spinal cord cross-sectional area (CSA)

# %% [markdown]
# ##### 3.1.1 All participants

# %%
plot_morphometrics(interpolated_morphometrics_df, 'CSA','CSA (mm²)')
plot_average_morphometrics(interpolated_morphometrics_df, 'CSA','CSA (mm²)')

# %% [markdown]
# ##### 3.1.2 Female

# %%
plot_morphometrics(interpolated_morphometrics_df, 'CSA','CSA (mm²)', sex='F')
plot_average_morphometrics(interpolated_morphometrics_df, 'CSA','CSA (mm²)', sex='F')

# %% [markdown]
# ##### 3.1.3 Male

# %%
plot_morphometrics(interpolated_morphometrics_df, 'CSA','CSA (mm²)', sex='M')
plot_average_morphometrics(interpolated_morphometrics_df, 'CSA','CSA (mm²)', sex='M')

# %% [markdown]
# #### 3.2 Antero-posterior (AP) diameter, right-left (RL) diameter

# %% [markdown]
# ##### 3.2.1 All participants

# %%
plot_average_morphometrics(interpolated_morphometrics_df, 'AP_diameter', 'AP Diameter (mm)')
plot_average_morphometrics(interpolated_morphometrics_df, 'RL_diameter', 'Transverse Diameter (mm)')
plot_morphometrics(interpolated_morphometrics_df, 'AP_diameter', 'AP Diameter (mm)')
plot_morphometrics(interpolated_morphometrics_df, 'RL_diameter', 'Transverse Diameter (mm)')

# %% [markdown]
# ##### 3.2.2 Female

# %%
plot_average_morphometrics(interpolated_morphometrics_df, 'AP_diameter', 'AP Diameter (mm)', sex='F')
plot_average_morphometrics(interpolated_morphometrics_df, 'RL_diameter', 'Transverse Diameter (mm)', sex='F')

# %% [markdown]
# ##### 3.2.3 Male

# %%
plot_average_morphometrics(interpolated_morphometrics_df, 'AP_diameter', 'AP Diameter (mm)', sex='M')
plot_average_morphometrics(interpolated_morphometrics_df, 'RL_diameter', 'Transverse Diameter (mm)', sex='M')

# %% [markdown]
# #### 3.3 CSA vs spinal cord length (normalized from PMJ to SC tip)

# %%
# interpolate to get the same number of points for every subject
per_slice_df_interp = interpolate_curves(per_slice_df, subject_col='subject', pos_col='Normalized_PMJ_SCtip', csa_col='MEAN(area)')
plot_morphometrics_SC_landmarks(per_slice_df_interp, 'Normalized_PMJ_SCtip', 'MEAN(area)','CSA (mm²)')

# %%
plot_difference_CSA_population_mean(interpolated_morphometrics_df, 'CSA','CSA (mm²)')

# %% [markdown]
# #### 3.4  CSA vs Age, for each vertebral level

# %%
# Anatomical labels
vertebral_label_map = {
    2.0: "C2",
    3.0: "C3",
    4.0: "C4",
    5.0: "C5",
    6.0: "C6",
    7.0: "C7",
    8.0: "T1",
    9.0: "T2",
    10.0: "T3",
    11.0: "T4",
    12.0: "T5",
    13.0: "T6",
    14.0: "T7",
    15.0: "T8",
    16.0: "T9",
    17.0: "T10",
    18.0: "T11",
    19.0: "T12",
    20.0: "L1"
}

# Prepare data
plot_df = per_vertlevel_df[["CSA", "age", "sex", "height", "weight", "VertLevel", "subject"]].dropna().copy()

# Make sure VertLevel is numeric
plot_df["VertLevel"] = pd.to_numeric(plot_df["VertLevel"])

# Create anatomical label column
plot_df["VertLabel"] = plot_df["VertLevel"].map(vertebral_label_map)

# Define desired order
level_order = list(vertebral_label_map.keys())

# Convert label to ordered categorical
plot_df["VertLabel"] = pd.Categorical(
    plot_df["VertLabel"],
    categories=[vertebral_label_map[x] for x in level_order],
    ordered=True
)

# Make sure sex is treated as categorical
plot_df["sex"] = plot_df["sex"].astype("category")


# Create plots
sns.set_theme()

g = sns.lmplot(
    data=plot_df,
    x="age",
    y="CSA",
    col="VertLabel",
    col_wrap=5,
    col_order=[vertebral_label_map[x] for x in level_order],
    height=3,
    aspect=1.2,
    scatter_kws={"alpha": 0.3, "s": 20},
    line_kws={"color": "red", "linewidth": 2},
    ci=95,
    sharex=False,
    sharey=False,
)

g.set_titles("{col_name}")

for ax in g.axes.flat:
    ax.set_xlabel("Age (years)")
    ax.set_ylabel("CSA")
    ax.xaxis.set_major_locator(MaxNLocator(integer=True)) # only integers as x ticks

# Run OLS at each vertebral level
# CSA ~ age + sex + height + weight

for ax, level in zip(g.axes.flat, [vertebral_label_map[x] for x in level_order]):

    # Data for this vertebral level
    level_df = plot_df[plot_df["VertLabel"] == level].copy()

    # OLS model
    model = smf.ols("CSA ~ age + C(sex) + height + weight", data=level_df).fit()

    # Extract p-values
    p_age = model.pvalues.get("age")
    p_height = model.pvalues.get("height")
    p_weight = model.pvalues.get("weight")
    p_sex = [
        v for k, v in model.pvalues.items()
        if k.startswith("C(sex)")
    ]
    p_sex = p_sex[0] if len(p_sex) > 0 else float("nan")

    # Text displayed on graph
    p_text = (
        f"Age: p={p_age:.3g}\n"
        f"Sex: p={p_sex:.3g}\n"
        f"Height: p={p_height:.3g}\n"
        f"Weight: p={p_weight:.3g}"
    )

    # Add text to upper-right corner
    ax.text(
        0.97, 0.97,
        p_text,
        transform=ax.transAxes,
        ha="right",
        va="top",
        fontsize=8,
        bbox=dict(
            boxstyle="round,pad=0.3",
            facecolor="white",
            alpha=0.8,
            edgecolor="gray"
        )
    )

plt.tight_layout()
plt.show()
# Out:
# /Users/samuellestonge/.pyenv/versions/3.12.2/lib/python3.12/site-packages/seaborn/regression.py:598: UserWarning:
#
# sharex is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#
# /Users/samuellestonge/.pyenv/versions/3.12.2/lib/python3.12/site-packages/seaborn/regression.py:598: UserWarning:
#
# sharey is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.

# %%
# Anatomical labels
vertebral_label_map = {
    2.0: "C2",
    3.0: "C3",
    4.0: "C4",
    5.0: "C5",
    6.0: "C6",
    7.0: "C7",
    8.0: "T1",
    9.0: "T2",
    10.0: "T3",
    11.0: "T4",
    12.0: "T5",
    13.0: "T6",
    14.0: "T7",
    15.0: "T8",
    16.0: "T9",
    17.0: "T10",
    18.0: "T11",
    19.0: "T12",
    20.0: "L1"
}

# Prepare data
plot_df = per_vertlevel_df[["CSA", "age", "sex", "height", "weight", "VertLevel", "subject"]].dropna().copy()

# Make sure VertLevel is numeric
plot_df["VertLevel"] = pd.to_numeric(plot_df["VertLevel"])

# Create anatomical label column
plot_df["VertLabel"] = plot_df["VertLevel"].map(vertebral_label_map)

# Define desired order
level_order = list(vertebral_label_map.keys())

# Convert label to ordered categorical
plot_df["VertLabel"] = pd.Categorical(
    plot_df["VertLabel"],
    categories=[vertebral_label_map[x] for x in level_order],
    ordered=True
)

# Make sure sex is treated as categorical
plot_df["sex"] = plot_df["sex"].astype("category")


# Create plots
sns.set_theme()

g = sns.lmplot(
    data=plot_df,
    x="age",
    y="CSA",
    col="VertLabel",
    col_wrap=5,
    col_order=[vertebral_label_map[x] for x in level_order],
    height=3,
    aspect=1.2,
    scatter_kws={"alpha": 0.3, "s": 20},
    line_kws={"color": "red", "linewidth": 2},
    ci=95,
    sharex=False,
    sharey=False,
)

g.set_titles("{col_name}")

for ax in g.axes.flat:
    ax.set_xlabel("Age (years)")
    ax.set_ylabel("CSA")
    ax.xaxis.set_major_locator(MaxNLocator(integer=True)) # only integers as x ticks

# Run OLS at each vertebral level
# CSA ~ age + sex + height + weight

for ax, level in zip(g.axes.flat, [vertebral_label_map[x] for x in level_order]):

    # Data for this vertebral level
    level_df = plot_df[plot_df["VertLabel"] == level].copy()

    # OLS model
    model = smf.ols("CSA ~ age", data=level_df).fit()

    # Extract p-values
    p_age = model.pvalues.get("age")

    # Text displayed on graph
    p_text = (f"Age: p={p_age:.3g}\n")

    # Add text to upper-right corner
    ax.text(
        0.97, 0.97,
        p_text,
        transform=ax.transAxes,
        ha="right",
        va="top",
        fontsize=8,
        bbox=dict(
            boxstyle="round,pad=0.3",
            facecolor="white",
            alpha=0.8,
            edgecolor="gray"
        )
    )

plt.tight_layout()
plt.show()
# Out:
# /Users/samuellestonge/.pyenv/versions/3.12.2/lib/python3.12/site-packages/seaborn/regression.py:598: UserWarning:
#
# sharex is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#
# /Users/samuellestonge/.pyenv/versions/3.12.2/lib/python3.12/site-packages/seaborn/regression.py:598: UserWarning:
#
# sharey is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.

# %%
region_map = {
    0.0: "Cervical",
    1.0: "Cervical",
    2.0: "Cervical",
    3.0: "Cervical",
    4.0: "Cervical",
    5.0: "Cervical",
    6.0: "Cervical",
    7.0: "Cervical",
    8.0: "Cervical",
    9.0: "Thoracic",
    10.0: "Thoracic",
    11.0: "Thoracic",
    12.0: "Thoracic",
    13.0: "Thoracic",
    14.0: "Thoracic",
    15.0: "Thoracic",
    16.0: "Thoracic",
    17.0: "Thoracic",
    18.0: "Thoracic",
    19.0: "Thoracic",
    20.0: "Lumbar",
    21.0: "Lumbar",
}

plot_df["Region"] = plot_df["VertLevel"].map(region_map)

region_order = ["Cervical", "Thoracic", "Lumbar"]

g = sns.lmplot(
    data=plot_df,
    x="age",
    y="CSA",
    col="Region",
    col_order=region_order,
    height=4,
    aspect=1.1,
    scatter_kws={"alpha": 0.25, "s": 20},
    line_kws={"color": "red", "linewidth": 2},
    ci=95, 
    sharex=False,
    sharey=False
)

g.set_axis_labels("Age (years)", "CSA")
g.set_titles("{col_name} region")

plt.tight_layout()
plt.show()
# Out:
# /Users/samuellestonge/.pyenv/versions/3.12.2/lib/python3.12/site-packages/seaborn/regression.py:598: UserWarning:
#
# sharex is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#
# /Users/samuellestonge/.pyenv/versions/3.12.2/lib/python3.12/site-packages/seaborn/regression.py:598: UserWarning:
#
# sharey is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.

# %% [markdown]
# ### 4. Statistical analyses

# %% [markdown]
# #### 4.1 Correlation between height and weight

# %%
per_vertlevel_df[["height", "weight"]].corr()
# Out:
#           height    weight
# height  1.000000  0.719957
# weight  0.719957  1.000000

# %%
per_vertlevel_df[["age", "height"]].corr()
# Out:
#              age    height
# age     1.000000  0.638535
# height  0.638535  1.000000

# %%
per_vertlevel_df[["age", "weight"]].corr()
# Out:
#              age    weight
# age     1.000000  0.556015
# weight  0.556015  1.000000

# %% [markdown]
# #### 4.1 Linear mixed model
#
# This model takes into consideration the repeated measures of each subject (measures for each vertebral level)

# %% [markdown]
# ##### 4.1.1 With age

# %%
import statsmodels.formula.api as smf 

cols = ["CSA", "age", "VertLevel", "subject"] 
df = per_vertlevel_df[cols].dropna().copy() 
df["subject"] = df["subject"].astype("category") 

model = smf.mixedlm( "CSA ~ age + C(VertLevel)", data=df, groups="subject" ) 

result = model.fit() 
print(result.summary())
# Out:
#               Mixed Linear Model Regression Results
# ...
# Model:               MixedLM    Dependent Variable:    CSA
# No. Observations:    1866       Method:                REML
# No. Groups:          94         Scale:                 35.4893
# Min. group size:     15         Log-Likelihood:        -6090.5575
# Max. group size:     20         Converged:             Yes
# Mean group size:     19.9
# -----------------------------------------------------------------
#                     Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------
# Intercept           59.680    2.402  24.848 0.000  54.973  64.387
# C(VertLevel)[T.2]   -2.998    0.869  -3.450 0.001  -4.701  -1.295
# C(VertLevel)[T.3]   -2.523    0.869  -2.904 0.004  -4.226  -0.820
# C(VertLevel)[T.4]    1.297    0.869   1.492 0.136  -0.406   3.000
# C(VertLevel)[T.5]    1.485    0.869   1.709 0.088  -0.218   3.188
# ...

# %% [markdown]
# ##### 4.1.2 With age and sex

# %%
import statsmodels.formula.api as smf 

cols = ["CSA", "age", "sex", "VertLevel", "subject"] 
df = per_vertlevel_df[cols].dropna().copy() 
df["sex"] = df["sex"].astype("category") 
df["subject"] = df["subject"].astype("category") 

model = smf.mixedlm("CSA ~ age + C(sex) + C(VertLevel)", data=df, groups="subject") 

result = model.fit() 
print(result.summary())
# Out:
#               Mixed Linear Model Regression Results
# ...
# Model:               MixedLM    Dependent Variable:    CSA
# No. Observations:    1866       Method:                REML
# No. Groups:          94         Scale:                 35.4892
# Min. group size:     15         Log-Likelihood:        -6089.4343
# Max. group size:     20         Converged:             Yes
# Mean group size:     19.9
# -----------------------------------------------------------------
#                     Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------
# Intercept           59.832    2.445  24.470 0.000  55.039  64.624
# C(sex)[T.M]         -0.434    1.144  -0.380 0.704  -2.676   1.807
# C(VertLevel)[T.2]   -2.998    0.869  -3.450 0.001  -4.701  -1.295
# C(VertLevel)[T.3]   -2.523    0.869  -2.904 0.004  -4.226  -0.820
# C(VertLevel)[T.4]    1.297    0.869   1.492 0.136  -0.406   3.000
# ...

# %% [markdown]
# ##### 4.1.2 With age, sex, and height

# %%
import statsmodels.formula.api as smf 

cols = ["CSA", "age", "sex", "height", "weight", "VertLevel", "subject"] 
df = per_vertlevel_df[cols].dropna().copy() 
df["sex"] = df["sex"].astype("category") 
df["subject"] = df["subject"].astype("category") 

model = smf.mixedlm("CSA ~ age + C(sex) + height + weight + C(VertLevel)", data=df, groups="subject" ) 

result = model.fit() 
print(result.summary())
# Out:
#               Mixed Linear Model Regression Results
# ...
# Model:               MixedLM    Dependent Variable:    CSA
# No. Observations:    1772       Method:                REML
# No. Groups:          89         Scale:                 35.5957
# Min. group size:     19         Log-Likelihood:        -5781.1502
# Max. group size:     20         Converged:             Yes
# Mean group size:     19.9
# -----------------------------------------------------------------
#                     Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------
# Intercept           57.555    8.077   7.126 0.000  41.724  73.386
# C(sex)[T.M]          0.270    1.223   0.221 0.825  -2.126   2.666
# C(VertLevel)[T.2]   -3.016    0.894  -3.372 0.001  -4.769  -1.263
# C(VertLevel)[T.3]   -2.603    0.894  -2.910 0.004  -4.356  -0.850
# C(VertLevel)[T.4]    1.235    0.894   1.381 0.167  -0.518   2.988
# ...

# %% [markdown]
# ##### 4.1.2 With age, sex, and height

# %%
import statsmodels.formula.api as smf 

cols = ["CSA", "age", "sex", "height", "VertLevel", "subject"] 
df = per_vertlevel_df[cols].dropna().copy() 
df["sex"] = df["sex"].astype("category") 
df["subject"] = df["subject"].astype("category") 

model = smf.mixedlm("CSA ~ age + C(sex) + height + C(VertLevel)", data=df, groups="subject" ) 

result = model.fit() 
print(result.summary())
# Out:
#               Mixed Linear Model Regression Results
# ...
# Model:               MixedLM    Dependent Variable:    CSA
# No. Observations:    1772       Method:                REML
# No. Groups:          89         Scale:                 35.5955
# Min. group size:     19         Log-Likelihood:        -5780.9626
# Max. group size:     20         Converged:             Yes
# Mean group size:     19.9
# -----------------------------------------------------------------
#                     Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------
# Intercept           49.596    7.020   7.065 0.000  35.837  63.356
# C(sex)[T.M]         -0.386    1.191  -0.324 0.746  -2.721   1.949
# C(VertLevel)[T.2]   -3.016    0.894  -3.372 0.001  -4.769  -1.263
# C(VertLevel)[T.3]   -2.603    0.894  -2.910 0.004  -4.356  -0.850
# C(VertLevel)[T.4]    1.235    0.894   1.381 0.167  -0.518   2.988
# ...

# %% [markdown]
# ##### 4.1.2 With age, sex, and weight

# %%
import statsmodels.formula.api as smf 

cols = ["CSA", "age", "sex", "weight", "VertLevel", "subject"] 
df = per_vertlevel_df[cols].dropna().copy() 
df["sex"] = df["sex"].astype("category") 
df["subject"] = df["subject"].astype("category") 

model = smf.mixedlm("CSA ~ age + C(sex) + weight + C(VertLevel)", data=df, groups="subject" ) 

result = model.fit() 
print(result.summary())
# Out:
#               Mixed Linear Model Regression Results
# ...
# Model:               MixedLM    Dependent Variable:    CSA
# No. Observations:    1772       Method:                REML
# No. Groups:          89         Scale:                 35.5957
# Min. group size:     19         Log-Likelihood:        -5783.9994
# Max. group size:     20         Converged:             Yes
# Mean group size:     19.9
# -----------------------------------------------------------------
#                     Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------
# Intercept           58.471    2.610  22.403 0.000  53.355  63.586
# C(sex)[T.M]          0.302    1.186   0.255 0.799  -2.021   2.626
# C(VertLevel)[T.2]   -3.016    0.894  -3.372 0.001  -4.769  -1.263
# C(VertLevel)[T.3]   -2.603    0.894  -2.910 0.004  -4.356  -0.850
# C(VertLevel)[T.4]    1.235    0.894   1.381 0.167  -0.518   2.988
# ...

# %% [markdown]
# ##### 4.1.3 With age, sex and height percentiles

# %%
import statsmodels.formula.api as smf 

cols = ["CSA", "age", "sex", "height_for_age_percentile", "weight_for_age_percentile", "VertLevel", "subject"] 
df = per_vertlevel_df[cols].dropna().copy() 
df["sex"] = df["sex"].astype("category") 
df["subject"] = df["subject"].astype("category") 

model = smf.mixedlm( "CSA ~ age + sex + height_for_age_percentile + VertLevel", data=df, groups="subject" ) 

result = model.fit() 
print(result.summary())
# Out:
#                 Mixed Linear Model Regression Results
# ...
# Model:                 MixedLM     Dependent Variable:     CSA
# No. Observations:      1772        Method:                 REML
# No. Groups:            89          Scale:                  137.5064
# Min. group size:       19          Log-Likelihood:         -6944.9055
# Max. group size:       20          Converged:              Yes
# Mean group size:       19.9
# ---------------------------------------------------------------------
#                           Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                 54.704    3.581  15.275 0.000 47.685 61.723
# sex[T.M]                   0.012    1.193   0.010 0.992 -2.327  2.350
# age                        0.955    0.220   4.333 0.000  0.523  1.387
# height_for_age_percentile  0.033    0.020   1.643 0.100 -0.006  0.073
# VertLevel                 -2.132    0.049 -43.950 0.000 -2.227 -2.037
# ...

# %% [markdown]
# ##### 4.1.3 With age, sex and weight percentiles

# %%
import statsmodels.formula.api as smf 

cols = ["CSA", "age", "sex", "height_for_age_percentile", "weight_for_age_percentile", "VertLevel", "subject"] 
df = per_vertlevel_df[cols].dropna().copy() 
df["sex"] = df["sex"].astype("category") 
df["subject"] = df["subject"].astype("category") 

model = smf.mixedlm( "CSA ~ age + sex + weight_for_age_percentile + VertLevel", data=df, groups="subject" ) 

result = model.fit() 
print(result.summary())
# Out:
#                 Mixed Linear Model Regression Results
# ...
# Model:                 MixedLM     Dependent Variable:     CSA
# No. Observations:      1772        Method:                 REML
# No. Groups:            89          Scale:                  137.5058
# Min. group size:       19          Log-Likelihood:         -6943.7896
# Max. group size:       20          Converged:              Yes
# Mean group size:       19.9
# ---------------------------------------------------------------------
#                           Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                 55.078    3.025  18.208 0.000 49.149 61.007
# sex[T.M]                   0.312    1.192   0.262 0.794 -2.024  2.648
# age                        0.884    0.197   4.487 0.000  0.498  1.271
# weight_for_age_percentile  0.043    0.019   2.274 0.023  0.006  0.079
# VertLevel                 -2.132    0.049 -43.949 0.000 -2.227 -2.037
# ...

# %%
results = []

for level in sorted(per_vertlevel_df["VertLevel"].unique()):

    # Filter dataset for the vertebral level
    df_level = per_vertlevel_df[per_vertlevel_df["VertLevel"] == level]

    # Get the number of participants with data for this vertebral level
    N_participants = df_level["subject"].nunique()

    model = smf.ols("CSA ~ age + C(sex) + height + weight", data=df_level).fit()

    results.append({
        "VertLevel": level,
        "coef_age": model.params["age"],
        "p_age": model.pvalues["age"],
        "coef_sex": model.params["C(sex)[T.M]"],
        "p_sex": model.pvalues["C(sex)[T.M]"],
        "coef_height": model.params["height"],
        "p_height": model.pvalues["height"],
        "coef_weight": model.params["weight"],
        "p_weight": model.pvalues["weight"],
        "r2": model.rsquared,
        "N_participants": N_participants
    })

results = pd.DataFrame(results)

pvalue_cols = ["p_age", "p_sex", "p_height", "p_weight"]

# Apply FDR correction (for multiple tests)
for col in pvalue_cols:
    results[col + "_FDR"] = multipletests(
        results[col],
        method="fdr_bh"
    )[1]

pvalue_cols_FDR = [
    "p_age_FDR",
    "p_sex_FDR",
    "p_height_FDR",
    "p_weight_FDR"
]

results.style.map(
    lambda x: "color: red; font-weight: bold" if x < 0.05 else "",
    subset=pvalue_cols_FDR,
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_62e5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62e5b_level0_col0" class="col_heading level0 col0" >VertLevel</th>
#       <th id="T_62e5b_level0_col1" class="col_heading level0 col1" >coef_age</th>
#       <th id="T_62e5b_level0_col2" class="col_heading level0 col2" >p_age</th>
#       <th id="T_62e5b_level0_col3" class="col_heading level0 col3" >coef_sex</th>
#       <th id="T_62e5b_level0_col4" class="col_heading level0 col4" >p_sex</th>
#       <th id="T_62e5b_level0_col5" class="col_heading level0 col5" >coef_height</th>
#       <th id="T_62e5b_level0_col6" class="col_heading level0 col6" >p_height</th>
#       <th id="T_62e5b_level0_col7" class="col_heading level0 col7" >coef_weight</th>
#       <th id="T_62e5b_level0_col8" class="col_heading level0 col8" >p_weight</th>
#       <th id="T_62e5b_level0_col9" class="col_heading level0 col9" >r2</th>
# ...
