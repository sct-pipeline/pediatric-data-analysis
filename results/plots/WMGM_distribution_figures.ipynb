# %% [markdown]
# # WM and GM distribution in the pediatric spinal cord
#
# This jupyter notebook includes scripts to generate figures related to the white matter and gray matter distribution in the pediatric spinal cord.

# %%
import os
import pandas as pd
import json
import yaml
import re
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import webbrowser
import statsmodels.formula.api as smf

# %% [markdown]
# ### Load config file to get path to dataset

# %%
# Load config file
with open('../../config/config_preprocessing.yaml' , 'r') as file:
    config = yaml.safe_load(file)

# Get data path from config file
path_data = config['path_data']

# %% [markdown]
# ### Get the `participants.tsv` file from the dataset

# %%
# Get path to participants.tsv file
participants_tsv = pd.read_csv(os.path.join(path_data, 'participants.tsv'), sep='\t')
participants_tsv
# Out:
#     participant_id  age sex    group scan_series  height     weight
# 0          sub-101   17   M  control    complete  1.7780  68.038855
# 1          sub-102   15   F  control    complete  1.6256  52.163123
# 2          sub-103   15   M  control    complete  1.6510  54.431084
# 3          sub-104   16   F  control    complete  1.6256  52.163123
# 4          sub-105   13   M  control    complete  1.5494  35.380205
# ..             ...  ...  ..      ...         ...     ...        ...
# 131        sub-235   13   M  control  incomplete  1.7272  51.709530
# 132        sub-236   13   M  control    complete  1.6510  53.523900
# 133        sub-237   13   M  control    complete  1.6002  45.359237
# 134        sub-238   15   F  control    complete     NaN        NaN
# 135        sub-239    6   F  control    complete     NaN        NaN
#
# [136 rows x 7 columns]

# %% [markdown]
# ## Dataframe of subjects included in the pipeline analysis
#
# The following dataframe contains only the subjects that were included in this pipeline analysis.

# %%
def get_list_of_subjects_to_include(contrast, path_data, missing_data_subjects):
    """
    This function takes an image contrast (T2w, dwi, etc.), a path to a dataset, and a list of subjects with missing data,
    and returns a list of subjects to include in the analysis.

    The dataset needs to be in BIDS format, and the function will look for the participants.tsv file to get the list of subjects.
    The dataset should also contain an `exclude.yml` file that lists subjects to exclude from the analysis.
    """

    # Get the `participants.tsv` file and read it into a dataframe
    participants_tsv = pd.read_csv(os.path.join(path_data, 'participants.tsv'), sep='\t')

    # Get all subject IDs from the participants.tsv
    all_subjects = participants_tsv['participant_id'].tolist()

    # Get list of subjects to exclude from the analysis from the `exclude.yml` file
    with open(os.path.join(path_data, 'exclude.yml'), 'r') as file:
        exclude_yml = yaml.safe_load(file)

    exclude_t2star_key = exclude_yml.get(contrast, []) # Extract subjects under contrast key
    exclude_subjects = sorted(set(re.match(r"(sub-\d+)", entry).group(1) for entry in exclude_t2star_key if re.match(r"(sub-\d+)", entry))) # Extract the subject ID 

    # Add the list of subjects with missing data to the exclude_subjects list
    exclude_subjects.extend(missing_data_subjects)
    
    # Remove duplicates (if any), sort and print the list of subjects to exclude from the analysis
    exclude_subjects = sorted(set(exclude_subjects))
    print(f'subjects to exclude : {exclude_subjects}')

    # Compute the list of subjects to include in the analysis 
    include_subjects = [sub for sub in all_subjects if sub not in exclude_subjects]

    # Convert the list of included subjects to a dataframe
    include_subjects = participants_tsv[participants_tsv['participant_id'].isin(include_subjects)]

    return include_subjects

# %%
# List of subjects with missing t2star data or missing T2w rootlet segmentation
missing_t2star_subjects = [
                        "sub-109",
                        "sub-125",
                        "sub-136",
                        "sub-152",
                        "sub-159",
                        "sub-174",
                        "sub-198",
                        "sub-200",
                        "sub-205",
                        "sub-211",
                        "sub-213",
                        "sub-221",
                        "sub-234",
                        "sub-235"]

missing_rootlets_subjects = ["sub-108", "sub-110", "sub-111", "sub-121", "sub-127", "sub-133", "sub-136", "sub-141", 
                             "sub-150", "sub-159", "sub-160", "sub-161", "sub-163", "sub-165", "sub-167", "sub-168", 
                             "sub-169", "sub-170", "sub-177", "sub-179", "sub-186", "sub-190", "sub-191", "sub-193", 
                             "sub-198", "sub-203", "sub-208", "sub-209", "sub-210", "sub-211", "sub-213", "sub-214", 
                             "sub-217", "sub-218"]

# Combine both lists of missing subjects
missing_subjects = missing_t2star_subjects + missing_rootlets_subjects
print(missing_subjects)

# Get the list of subjects to include in the analysis
include_t2star_subjects = get_list_of_subjects_to_include('t2starw', path_data, missing_subjects)
include_t2star_subjects.to_csv(os.path.join('../tables/GM_WM_distribution/include_t2star_subjects.csv'), sep='\t', index=False)

print(include_t2star_subjects.shape[0], "subjects to include in the analysis")
print(f"\n list of subjects to include : \n {include_t2star_subjects['participant_id'].tolist()}")

include_t2star_subjects
# Out:
# ['sub-109', 'sub-125', 'sub-136', 'sub-152', 'sub-159', 'sub-174', 'sub-198', 'sub-200', 'sub-205', 'sub-211', 'sub-213', 'sub-221', 'sub-234', 'sub-235', 'sub-108', 'sub-110', 'sub-111', 'sub-121', 'sub-127', 'sub-133', 'sub-136', 'sub-141', 'sub-150', 'sub-159', 'sub-160', 'sub-161', 'sub-163', 'sub-165', 'sub-167', 'sub-168', 'sub-169', 'sub-170', 'sub-177', 'sub-179', 'sub-186', 'sub-190', 'sub-191', 'sub-193', 'sub-198', 'sub-203', 'sub-208', 'sub-209', 'sub-210', 'sub-211', 'sub-213', 'sub-214', 'sub-217', 'sub-218']
# subjects to exclude : ['sub-106', 'sub-107', 'sub-108', 'sub-109', 'sub-110', 'sub-111', 'sub-120', 'sub-121', 'sub-124', 'sub-125', 'sub-127', 'sub-133', 'sub-136', 'sub-139', 'sub-141', 'sub-144', 'sub-150', 'sub-152', 'sub-154', 'sub-159', 'sub-160', 'sub-161', 'sub-163', 'sub-165', 'sub-167', 'sub-168', 'sub-169', 'sub-170', 'sub-171', 'sub-172', 'sub-174', 'sub-177', 'sub-179', 'sub-181', 'sub-186', 'sub-188', 'sub-189', 'sub-190', 'sub-191', 'sub-193', 'sub-194', 'sub-196', 'sub-198', 'sub-199', 'sub-200', 'sub-203', 'sub-204', 'sub-205', 'sub-207', 'sub-208', 'sub-209', 'sub-210', 'sub-211', 'sub-212', 'sub-213', 'sub-214', 'sub-217', 'sub-218', 'sub-221', 'sub-225', 'sub-228', 'sub-231', 'sub-232', 'sub-234', 'sub-235', 'sub-236', 'sub-238', 'sub-239']
# 68 subjects to include in the analysis
#
#  list of subjects to include :
#  ['sub-101', 'sub-102', 'sub-103', 'sub-104', 'sub-105', 'sub-112', 'sub-113', 'sub-114', 'sub-115', 'sub-116', 'sub-117', 'sub-118', 'sub-119', 'sub-122', 'sub-123', 'sub-126', 'sub-128', 'sub-129', 'sub-130', 'sub-131', 'sub-132', 'sub-134', 'sub-135', 'sub-137', 'sub-138', 'sub-140', 'sub-142', 'sub-143', 'sub-145', 'sub-146', 'sub-147', 'sub-148', 'sub-149', 'sub-151', 'sub-153', 'sub-155', 'sub-156', 'sub-158', 'sub-162', 'sub-164', 'sub-166', 'sub-173', 'sub-175', 'sub-176', 'sub-178', 'sub-180', 'sub-182', 'sub-183', 'sub-184', 'sub-185', 'sub-192', 'sub-197', 'sub-201', 'sub-202', 'sub-206', 'sub-215', 'sub-216', 'sub-219', 'sub-220', 'sub-222', 'sub-223', 'sub-224', 'sub-226', 'sub-227', 'sub-229', 'sub-230', 'sub-233', 'sub-237']
#     participant_id  age sex    group scan_series  height     weight
# 0          sub-101   17   M  control    complete  1.7780  68.038855
# 1          sub-102   15   F  control    complete  1.6256  52.163123
# 2          sub-103   15   M  control    complete  1.6510  54.431084
# 3          sub-104   16   F  control    complete  1.6256  52.163123
# 4          sub-105   13   M  control    complete  1.5494  35.380205
# ..             ...  ...  ..      ...         ...     ...        ...
# 123        sub-227   11   F  control    complete  1.2446  43.091275
# 125        sub-229   10   M  control    complete  1.5494  59.874193
# 126        sub-230   11   F  control    complete  1.6256  68.038855
# 129        sub-233   16   M  control    complete  1.6764  54.431084
# 133        sub-237   13   M  control    complete  1.6002  45.359237
#
# [68 rows x 7 columns]

# %% [markdown]
# ## Plot demographics
#
# This function plots the age and sex distribution of the subjects included in a pipeline analysis, according to the include list generated above.

# %%
def plot_demographics(df):
    """
    This function plots the demographic information of participants, given a dataframe with the list of subjects to include in the analysis.
    """

    # Sort by sex
    df_M = df[df['sex'] == 'M']
    df_F = df[df['sex'] == 'F']

    # Round down age to nearest month 
    df['age'] = np.floor(df['age']) 

    # Create subplot
    fig = make_subplots(rows=1, cols=1)

    # Add histogram for female subjects
    fig.add_trace(go.Histogram(
        x=df_F['age'], 
        name='F', 
        marker=dict(color= "#D19D88"),
        opacity=1.0,
        legendgroup='F',
        ),
        row=1, col=1
    )

    # Add histogram for male subjects
    fig.add_trace(go.Histogram(
        x=df_M['age'], 
        name='M', 
        
        marker=dict(color="#5C8EA1"),
        opacity=1.0,
        legendgroup='M',
        ), 
        row=1, col=1
    )

    # Define age tick range
    tick_vals = list(range(6, 18)) 

    # Update layout
    fig.update_layout(
        width=900,
        height=500,
        font=dict(family='Arial', size=20, color='black'), 
        legend=dict(
            orientation="h", 
            yanchor="bottom", 
            y=1.0, 
            xanchor="center",  
            x=0.5,
        ),
        xaxis=dict(
            range=[5, 18],  # Set x-axis range from 6 to 17
        ),
        plot_bgcolor='white',
        barmode='stack',
        bargap=0.3,  
        xaxis_title='Age (years)',
        xaxis_title_font=dict(family='Arial', size=20, weight='bold'),
        yaxis_title='Number of Subjects',
        yaxis_title_font=dict(family='Arial', size=20, weight='bold'),
        xaxis_title_standoff=50, 
    )

    fig.update_xaxes(
        tickmode='array',
        tickvals=tick_vals,
        showgrid=False,
        gridwidth=1
    )

    fig.update_yaxes(
        showgrid=True,             # Horizontal grid lines
        gridcolor='lightgrey',
        gridwidth=1
    )

    # Set bin size to 1 year
    fig.update_traces(xbins=dict(size=1))

    fig.show()

# %%
# Plot demographics for included subjects in DWI analysis
plot_demographics(include_t2star_subjects)

# %% [markdown]
# # Create a dataframe for GM, WM and SC CSA (all subjects combined)

# %%
# Path to WM, GM and SC CSA (one file per subject)
CSA_base_folder = "../tables/GM_WM_distribution/"
labels = ['WM', 'GM', 'SC']

WMGM_distribution_df = {}

for label in labels:
    label_folder = os.path.join(CSA_base_folder, label)
    label_dfs = []

    if not os.path.exists(label_folder):
        print(f"Folder not found: {label_folder}")
        continue
    
    for filename in os.listdir(label_folder):
        if filename.endswith(".csv"):
            if not any(sub in filename for sub in include_t2star_subjects['participant_id'].tolist()):
                continue  # Skip subjects not in the include list
            subject_path = os.path.join(label_folder, filename)
            df = pd.read_csv(subject_path)
            subject_id = filename.split("_")[0]  # Or use regex for more robust parsing
            df["participant_id"] = subject_id
            label_dfs.append(df)
    
    if label_dfs:
        WMGM_distribution_df[label] = pd.concat(label_dfs, ignore_index=True)
    else:
        print(f"Warning: No CSV files found for label {label}")
        WMGM_distribution_df[label] = pd.DataFrame()

# Add age and sex to DTI metric dataframe
for label in WMGM_distribution_df:
    WMGM_distribution_df[label] = WMGM_distribution_df[label].merge(include_t2star_subjects, on="participant_id", how="left")

# %%
# Save combined WM, GM and SC CSA dataframes to csv files

df_WM = WMGM_distribution_df['WM']
#WMGM_distribution_df['WM'].to_csv('../tables/GM_WM_distribution/WM/WM_CSA.csv', index=False)

df_GM = WMGM_distribution_df['GM']
#WMGM_distribution_df['GM'].to_csv('../tables/GM_WM_distribution/GM/GM_CSA.csv', index=False)

df_SC = WMGM_distribution_df['SC']
#WMGM_distribution_df['SC'].to_csv('../tables/GM_WM_distribution/SC/SC_CSA.csv', index=False)

# %%
df_SC
# Out:
#                Timestamp  SCT Version  \
# 0    2026-07-09 23:05:35          7.1
# 1    2026-07-09 23:04:26          7.1
# 2    2026-07-09 23:04:28          7.1
# 3    2026-07-09 23:04:32          7.1
# 4    2026-07-09 23:04:34          7.1
# ..                   ...          ...
# 401  2026-07-09 23:06:01          7.1
# 402  2026-07-09 23:06:03          7.1
# 403  2026-07-09 23:06:07          7.1
# 404  2026-07-09 23:06:09          7.1
# 405  2026-07-09 23:06:05          7.1
#
#                                               Filename Slice (I->S)  \
# 0    /Users/samuellestonge/Documents/datasets/phila...          5:6
# 1    /Users/samuellestonge/Documents/datasets/phila...        11:12
# 2    /Users/samuellestonge/Documents/datasets/phila...         8:10
# 3    /Users/samuellestonge/Documents/datasets/phila...          2:3
# 4    /Users/samuellestonge/Documents/datasets/phila...         2:14
# ..                                                 ...          ...
# 401  /Users/samuellestonge/Documents/datasets/phila...         8:10
# 402  /Users/samuellestonge/Documents/datasets/phila...          5:7
# 403  /Users/samuellestonge/Documents/datasets/phila...          0:1
# 404  /Users/samuellestonge/Documents/datasets/phila...         0:13
# 405  /Users/samuellestonge/Documents/datasets/phila...          2:4
#
#      VertLevel  DistancePMJ  MEAN(area)  STD(area)  MEAN(angle_AP)  \
# 0          NaN          NaN   67.001564   2.557635        1.444220
# 1          NaN          NaN   72.179111   1.186971        4.031516
# 2          NaN          NaN   67.536966   3.031030        2.172522
# 3          NaN          NaN   71.307166   0.649065       -0.477210
# 4          NaN          NaN   71.548554   3.525123        2.065735
# ..         ...          ...         ...        ...             ...
# 401        NaN          NaN   77.610264   0.841413       -1.446457
# 402        NaN          NaN   83.605233   0.726333       -1.047910
# 403        NaN          NaN   82.826425   2.773693       -1.181580
# 404        NaN          NaN   81.093328   3.876910       -1.381628
# 405        NaN          NaN   85.245847   2.070007       -0.985133
#
#      STD(angle_AP)  ...  STD(solidity)  SUM(length)  Spinal_Level  \
# 0         0.034301  ...       0.000470    10.018033             4
# 1         0.422219  ...       0.000521    10.129460             4
# 2         0.535057  ...       0.003387    15.066830             5
# 3         0.077407  ...       0.000754    10.009539             7
# 4         2.211153  ...       0.006772    65.460274    all_levels
# ..             ...  ...            ...          ...           ...
# 401       0.154392  ...       0.003597    15.010931             4
# 402       0.063400  ...       0.003492    15.085114             5
# 403       0.064162  ...       0.004734    10.299462             7
# 404       0.469623  ...       0.004165    70.751724    all_levels
# 405       0.029938  ...       0.000873    15.260948             6
#
#      participant_id  age  sex    group  scan_series  height     weight
# 0           sub-162   12    F  control     complete  1.5494  40.823313
# 1           sub-101   17    M  control     complete  1.7780  68.038855
# 2           sub-101   17    M  control     complete  1.7780  68.038855
# 3           sub-101   17    M  control     complete  1.7780  68.038855
# 4           sub-101   17    M  control     complete  1.7780  68.038855
# ..              ...  ...  ...      ...          ...     ...        ...
# 401         sub-192   17    F  control     complete  1.6764  56.699046
# 402         sub-192   17    F  control     complete  1.6764  56.699046
# 403         sub-192   17    F  control     complete  1.6764  56.699046
# 404         sub-192   17    F  control     complete  1.6764  56.699046
# 405         sub-192   17    F  control     complete  1.6764  56.699046
#
# [406 rows x 31 columns]

# %% [markdown]
# # Merge WM and GM dataframes and compute WM/GM ratio, GM/SC ratio and WM/SC ratio

# %%
# Merge WM and GM dataframes
df_GM_WM = df_WM.merge(
    df_GM,
    on=['participant_id', 'Spinal_Level', 'age', 'sex'], 
    suffixes=('_WM', '_GM')
)

# Add "_SC" suffix to df_SC columns except for the merge keys
df_SC = df_SC.rename(columns={col: f"{col}_SC" for col in df_SC.columns if col not in ['participant_id', 'Spinal_Level', 'age', 'sex']})

# Merge SC dataframe to the dataframe with WM and GM
df_GM_WM_SC = df_GM_WM.merge(
    df_SC, 
    on=['participant_id', 'Spinal_Level', 'age', 'sex']
)

df_GM_WM_SC.columns
# Out:
# Index(['Timestamp_WM', 'SCT Version_WM', 'Filename_WM', 'Slice (I->S)_WM',
#        'VertLevel_WM', 'DistancePMJ_WM', 'MEAN(area)_WM', 'STD(area)_WM',
#        'MEAN(angle_AP)_WM', 'STD(angle_AP)_WM', 'MEAN(angle_RL)_WM',
#        'STD(angle_RL)_WM', 'MEAN(diameter_AP)_WM', 'STD(diameter_AP)_WM',
#        'MEAN(diameter_RL)_WM', 'STD(diameter_RL)_WM', 'MEAN(eccentricity)_WM',
#        'STD(eccentricity)_WM', 'MEAN(orientation)_WM', 'STD(orientation)_WM',
#        'MEAN(solidity)_WM', 'STD(solidity)_WM', 'SUM(length)_WM',
#        'Spinal_Level', 'participant_id', 'age', 'sex', 'group_WM',
#        'scan_series_WM', 'height_WM', 'weight_WM', 'Timestamp_GM',
#        'SCT Version_GM', 'Filename_GM', 'Slice (I->S)_GM', 'VertLevel_GM',
#        'DistancePMJ_GM', 'MEAN(area)_GM', 'STD(area)_GM', 'MEAN(angle_AP)_GM',
#        'STD(angle_AP)_GM', 'MEAN(angle_RL)_GM', 'STD(angle_RL)_GM',
#        'MEAN(diameter_AP)_GM', 'STD(diameter_AP)_GM', 'MEAN(diameter_RL)_GM',
#        'STD(diameter_RL)_GM', 'MEAN(eccentricity)_GM', 'STD(eccentricity)_GM',
#        'MEAN(orientation)_GM', 'STD(orientation)_GM', 'MEAN(solidity)_GM',
#        'STD(solidity)_GM', 'SUM(length)_GM', 'group_GM', 'scan_series_GM',
#        'height_GM', 'weight_GM', 'Timestamp_SC', 'SCT Version_SC',
#        'Filename_SC', 'Slice (I->S)_SC', 'VertLevel_SC', 'DistancePMJ_SC',
#        'MEAN(area)_SC', 'STD(area)_SC', 'MEAN(angle_AP)_SC',
#        'STD(angle_AP)_SC', 'MEAN(angle_RL)_SC', 'STD(angle_RL)_SC',
#        'MEAN(diameter_AP)_SC', 'STD(diameter_AP)_SC', 'MEAN(diameter_RL)_SC',
#        'STD(diameter_RL)_SC', 'MEAN(eccentricity)_SC', 'STD(eccentricity)_SC',
#        'MEAN(orientation)_SC', 'STD(orientation)_SC', 'MEAN(solidity)_SC',
#        'STD(solidity)_SC', 'SUM(length)_SC', 'group_SC', 'scan_series_SC',
#        'height_SC', 'weight_SC'],
#       dtype='object')

# %%
df_GM_WM_SC
# Out:
#             Timestamp_WM  SCT Version_WM  \
# 0    2026-07-09 23:05:27             7.1
# 1    2026-07-09 23:05:29             7.1
# 2    2026-07-09 23:05:31             7.1
# 3    2026-07-09 23:05:25             7.1
# 4    2026-07-09 23:05:23             7.1
# ..                   ...             ...
# 401  2026-07-09 23:05:39             7.1
# 402  2026-07-09 23:05:35             7.1
# 403  2026-07-09 23:05:41             7.1
# 404  2026-07-09 23:05:33             7.1
# 405  2026-07-09 23:05:31             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 0    /Users/samuellestonge/Documents/datasets/phila...             2:4
# 1    /Users/samuellestonge/Documents/datasets/phila...             0:1
# 2    /Users/samuellestonge/Documents/datasets/phila...            0:12
# 3    /Users/samuellestonge/Documents/datasets/phila...             5:7
# 4    /Users/samuellestonge/Documents/datasets/phila...             8:9
# ..                                                 ...             ...
# 401  /Users/samuellestonge/Documents/datasets/phila...             0:1
# 402  /Users/samuellestonge/Documents/datasets/phila...             3:5
# 403  /Users/samuellestonge/Documents/datasets/phila...            0:11
# 404  /Users/samuellestonge/Documents/datasets/phila...             6:7
# 405  /Users/samuellestonge/Documents/datasets/phila...            8:11
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 0             NaN             NaN      61.300003      4.364803
# 1             NaN             NaN      62.816458      0.877176
# 2             NaN             NaN      60.387836      2.690938
# 3             NaN             NaN      58.827611      1.698180
# 4             NaN             NaN      60.227878      0.260861
# ..            ...             ...            ...           ...
# 401           NaN             NaN      59.564615      1.807090
# 402           NaN             NaN      59.579088      1.441259
# 403           NaN             NaN      56.654399      4.658251
# 404           NaN             NaN      56.028857      0.466785
# 405           NaN             NaN      51.122661      1.031887
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  STD(eccentricity)_SC  \
# 0            -0.350735          0.014703  ...              0.008509
# 1            -0.476359          0.044769  ...              0.003553
# 2            -0.632134          0.327167  ...              0.025083
# 3            -0.435720          0.059625  ...              0.006297
# 4            -0.702973          0.073091  ...              0.001233
# ..                 ...               ...  ...                   ...
# 401           1.149085          0.276341  ...              0.000795
# 402           2.555740          0.214142  ...              0.004854
# 403           2.386701          0.643941  ...              0.005047
# 404           2.966345          0.026762  ...              0.004263
# 405           2.711901          0.222513  ...              0.004906
#
#      MEAN(orientation)_SC  STD(orientation)_SC  MEAN(solidity)_SC  \
# 0                1.995023             0.562156           0.979268
# 1                2.499936             0.566569           0.978932
# 2                3.150648             0.897597           0.978726
# 3                3.455386             0.381938           0.973531
# 4                4.214141             0.058587           0.980217
# ..                    ...                  ...                ...
# 401              1.254638             0.120186           0.981586
# 402              1.647690             0.023690           0.976035
# 403              2.334083             1.220728           0.978858
# 404              2.429449             0.462182           0.982297
# 405              3.721959             0.953212           0.977988
#
#      STD(solidity)_SC  SUM(length)_SC  group_SC  scan_series_SC  height_SC  \
# 0            0.002620       15.008764   control        complete     1.6002
# 1            0.002765       10.010993   control        complete     1.6002
# 2            0.003867       65.060729   control        complete     1.6002
# 3            0.002948       15.001372   control        complete     1.6002
# 4            0.001369       10.003936   control        complete     1.6002
# ..                ...             ...       ...             ...        ...
# 401          0.006244       10.032520   control        complete     1.4224
# 402          0.006220       15.022596   control        complete     1.4224
# 403          0.005565       60.223873   control        complete     1.4224
# 404          0.001640       10.039870   control        complete     1.4224
# 405          0.005161       20.124046   control        complete     1.4224
#
#      weight_SC
# 0    81.193034
# 1    81.193034
# 2    81.193034
# 3    81.193034
# 4    81.193034
# ..         ...
# 401  29.211349
# 402  29.211349
# 403  29.211349
# 404  29.211349
# 405  29.211349
#
# [406 rows x 85 columns]

# %%
# Compute WM/GM ratio
df_GM_WM_SC['GM_WM_ratio'] = df_GM_WM_SC['MEAN(area)_GM'] / df_GM_WM_SC['MEAN(area)_WM'].values

# Compute GM/SC ratio and GM percentage
df_GM_WM_SC['GM_SC_ratio'] = df_GM_WM_SC['MEAN(area)_GM'] / df_GM_WM_SC['MEAN(area)_SC'].values
df_GM_WM_SC['GM_percentage'] = df_GM_WM_SC['GM_SC_ratio']*100

# Compute WM/SC ratio and WM percentage
df_GM_WM_SC['WM_SC_ratio'] = df_GM_WM_SC['MEAN(area)_WM'] / df_GM_WM_SC['MEAN(area)_SC'].values
df_GM_WM_SC['WM_percentage'] = df_GM_WM_SC['WM_SC_ratio']*100

# %% [markdown]
# ## Plot GM, WM and SC CSA with age using spinal levels

# %%
def plot_CSA_all_labels(df, sex=None):
    """
    Plots CSA (WM, GM, SC) across vertebral levels as a function of age.
    Fits OLS regressions for each label and displays confidence intervals and p-values.

    Args:
        df (pd.DataFrame): DataFrame containing columns:
            'age', 'sex', 'Spinal_Level', and 'MEAN(area)_WM', 'MEAN(area)_GM', 'MEAN(area)_SC'.
    """

    df = df.copy()

    # Filter by sex (optional)
    if sex is not None:
        if 'sex' not in df.columns:
            raise ValueError("Column 'sex' not found in dataframe.")
        df = df[df['sex'] == sex].copy()

    vert_levels = ['3', '4', '5', '6', '7', 'all_levels']
    labels = ['WM', 'GM', 'SC']

    colors = {
    'WM': 'rgba(31, 119, 180, 1)',   # blue
    'GM': 'rgba(255, 127, 14, 1)',   # orange
    'SC': 'rgba(44, 160, 44, 1)',    # green
    }
    
    ci_colors = {
        'WM': 'rgba(31, 119, 180, 0.2)',
        'GM': 'rgba(255, 127, 14, 0.2)',
        'SC': 'rgba(44, 160, 44, 0.2)',
    }

    fig = make_subplots(
        rows=len(vert_levels),
        cols=1,
        shared_xaxes=False,
        shared_yaxes=False,
        vertical_spacing=0.04,
        horizontal_spacing=0.1
    )

    for row_idx, vert in enumerate(vert_levels, start=1):
        data = df[df['Spinal_Level'] == vert].copy()
        if data.empty:
            continue

        x_range = np.linspace(data['age'].min(), data['age'].max(), 100)

        # Create empty dictionnaries for OLS regression models and p-values
        models = {}
        pvals = {}

        # Get the metric column name for each label
        for label in labels:
            metric_col = f'MEAN(area)_{label}'
            if metric_col not in data.columns:
                continue

            # Fit OLS model
            ols_model = smf.ols(formula=f'Q("{metric_col}") ~ age', data=data).fit()

            models[label] = ols_model
            pvals[label] = ols_model.pvalues["age"]

            pred_df = pd.DataFrame({"age": x_range})
            pred = ols_model.get_prediction(pred_df).summary_frame(alpha=0.05)

            y_fit = pred['mean']
            ci_lower = pred['mean_ci_lower']
            ci_upper = pred['mean_ci_upper']

            # Scatter data
            fig.add_trace(
                go.Scatter(
                    x=data['age'],
                    y=data[metric_col],
                    mode='markers',
                    marker=dict(color=colors[label], size=9, opacity=0.6),
                    name=f'{label} (C{vert})',
                    showlegend=(row_idx == 1)  # show legend only for first subplot
                ),
                row=row_idx, col=1
            )

            # Regression line
            fig.add_trace(
                go.Scatter(
                    x=x_range,
                    y=y_fit,
                    mode='lines',
                    line=dict(color=colors[label], width=2),
                    name=f'{label} fit',
                    showlegend=False
                ),
                row=row_idx, col=1
            )

            # Confidence interval
            fig.add_trace(
                go.Scatter(
                    x=np.concatenate([x_range, x_range[::-1]]),
                    y=np.concatenate([ci_upper, ci_lower[::-1]]),
                    fill='toself',
                    fillcolor=ci_colors[label],
                    line=dict(color='rgba(255,255,255,0)'),
                    hoverinfo='skip',
                    showlegend=False
                ),
                row=row_idx, col=1
            )

        # Add p-value annotation
        text_lines = []

        for label in labels:

            if label not in pvals:
                continue

            p = pvals[label]

            color = "red" if p < 0.05 else "black"
            star = "*" if p < 0.05 else ""

            text_lines.append(
                f"<span style='color:{color};'>"
                f"p-{label} = {p:.3f}{star}"
                f"</span>"
            )

        fig.add_annotation(
            x=0.02,
            y=0.98,
            xref="x domain",
            yref="y domain",
            text="<br>".join(text_lines),
            align="left",
            showarrow=False,
            font=dict(
                size=12,
                family="Arial",
                color="black"
            ),
            bgcolor="rgba(255,255,255,0.75)",
            bordercolor="black",
            borderwidth=1.5,
            borderpad=6,
            row=row_idx,
            col=1
        )


        # Axes
        fig.update_xaxes(
            title_text='Age',
            title_font=dict(size=18, family='Arial', color='black', weight='bold'),
            tickfont=dict(size=16, family='Arial', color='black'),
            tickvals=list(range(6, 18)),
            range=[5, 18],  
            row=row_idx, col=1
        )

        fig.update_yaxes(
            title_text=f'CSA in C{vert} (mm²)',
            title_font=dict(size=20, family='Arial', color='black', weight='bold'),
            tickfont=dict(size=16, family='Arial', color='black'),
            range=[0, 90],
            row=row_idx, col=1
        )

        # Layout
        fig.update_layout(
            height=2200,
            width=600,
            plot_bgcolor='white',
            paper_bgcolor='white',
            legend=dict(
                orientation="h",
                yanchor="bottom",
                y=1.02,
                xanchor="center",
                x=0.5,
                font=dict(size=14)
            )
        )

    fig.show()

# %%
df_GM_WM_SC
# Out:
#             Timestamp_WM  SCT Version_WM  \
# 0    2026-07-09 23:05:27             7.1
# 1    2026-07-09 23:05:29             7.1
# 2    2026-07-09 23:05:31             7.1
# 3    2026-07-09 23:05:25             7.1
# 4    2026-07-09 23:05:23             7.1
# ..                   ...             ...
# 401  2026-07-09 23:05:39             7.1
# 402  2026-07-09 23:05:35             7.1
# 403  2026-07-09 23:05:41             7.1
# 404  2026-07-09 23:05:33             7.1
# 405  2026-07-09 23:05:31             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 0    /Users/samuellestonge/Documents/datasets/phila...             2:4
# 1    /Users/samuellestonge/Documents/datasets/phila...             0:1
# 2    /Users/samuellestonge/Documents/datasets/phila...            0:12
# 3    /Users/samuellestonge/Documents/datasets/phila...             5:7
# 4    /Users/samuellestonge/Documents/datasets/phila...             8:9
# ..                                                 ...             ...
# 401  /Users/samuellestonge/Documents/datasets/phila...             0:1
# 402  /Users/samuellestonge/Documents/datasets/phila...             3:5
# 403  /Users/samuellestonge/Documents/datasets/phila...            0:11
# 404  /Users/samuellestonge/Documents/datasets/phila...             6:7
# 405  /Users/samuellestonge/Documents/datasets/phila...            8:11
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 0             NaN             NaN      61.300003      4.364803
# 1             NaN             NaN      62.816458      0.877176
# 2             NaN             NaN      60.387836      2.690938
# 3             NaN             NaN      58.827611      1.698180
# 4             NaN             NaN      60.227878      0.260861
# ..            ...             ...            ...           ...
# 401           NaN             NaN      59.564615      1.807090
# 402           NaN             NaN      59.579088      1.441259
# 403           NaN             NaN      56.654399      4.658251
# 404           NaN             NaN      56.028857      0.466785
# 405           NaN             NaN      51.122661      1.031887
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 0            -0.350735          0.014703  ...       15.008764   control
# 1            -0.476359          0.044769  ...       10.010993   control
# 2            -0.632134          0.327167  ...       65.060729   control
# 3            -0.435720          0.059625  ...       15.001372   control
# 4            -0.702973          0.073091  ...       10.003936   control
# ..                 ...               ...  ...             ...       ...
# 401           1.149085          0.276341  ...       10.032520   control
# 402           2.555740          0.214142  ...       15.022596   control
# 403           2.386701          0.643941  ...       60.223873   control
# 404           2.966345          0.026762  ...       10.039870   control
# 405           2.711901          0.222513  ...       20.124046   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 0          complete     1.6002  81.193034     0.275756     0.216149
# 1          complete     1.6002  81.193034     0.253924     0.202449
# 2          complete     1.6002  81.193034     0.251579     0.200998
# 3          complete     1.6002  81.193034     0.269127     0.212057
# 4          complete     1.6002  81.193034     0.250947     0.200596
# ..              ...        ...        ...          ...          ...
# 401        complete     1.4224  29.211349     0.242742     0.195361
# 402        complete     1.4224  29.211349     0.254167     0.202664
# 403        complete     1.4224  29.211349     0.231178     0.187771
# 404        complete     1.4224  29.211349     0.226626     0.184757
# 405        complete     1.4224  29.211349     0.208755     0.172682
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 0        21.614861     0.783840      78.384000
# 1        20.244878     0.797282      79.728152
# 2        20.099786     0.798946      79.894647
# 3        21.205655     0.787943      78.794290
# 4        20.059550     0.799355      79.935485
# ..             ...          ...            ...
# 401      19.536141     0.804811      80.481071
# 402      20.266437     0.797367      79.736709
# 403      18.777087     0.812236      81.223628
# 404      18.475715     0.815250      81.525037
# 405      17.268172     0.827199      82.719878
#
# [406 rows x 90 columns]

# %%
plot_CSA_all_labels(df_GM_WM_SC)

# %%
plot_CSA_all_labels(df_GM_WM_SC, sex='F')

# %%
plot_CSA_all_labels(df_GM_WM_SC, sex='M')

# %% [markdown]
# ## Plot GM and WM percentages with respect to age

# %%
def plot_ratio(df, label_1, label_2, y_min, y_max):

    """
    This function plots the ratio between two labels (e.g., GM and WM) across different spinal levels. The ratio is computed as : label_1 / label_2

    Args:
        df (pd.DataFrame): DataFrame containing the data to plot. Must include columns 'age', 'sex', 'VertLevel', and the ratio column. 
        The ratio column should be named as '{label_1}_{label_2}_ratio'.
        label (str): The label we want to plot (in %) ('GM' or 'WM').
    """
    
    df = df.copy()

    # Vertebral levels to plot
    vert_levels = ['3', '4', '5', '6', '7', 'all_levels']

    # Define color of markers 
    color = "#222020"

    # Color for confidence interval
    ci_color = 'rgba(34, 32, 32, 0.35)' 

    fig = make_subplots(
        rows=6,
        cols=1,
        shared_xaxes=False,
        shared_yaxes=False,
        vertical_spacing=0.05,
        horizontal_spacing=0.1
    )

    for row_idx, vert in enumerate(vert_levels, start=1):

        # Filder data according to the VertLevel
        data = df[df['Spinal_Level'] == vert].copy()

        print(data)

        x_range = np.linspace(data['age'].min(), data['age'].max(), 100)
        pred_df = pd.DataFrame({'age': x_range})

        ratio_name = f'{label_1}_{label_2}_ratio'
        ols_formula = f'{ratio_name} ~ age'

        ols_model = smf.ols(formula=ols_formula, data=data)
        ols_results = ols_model.fit()

        # Print OLS results
        print(ols_results.summary())

        pred = ols_results.get_prediction(pred_df)
        pred_summary = pred.summary_frame(alpha=0.05)

        y_fit = pred_summary['mean']
        ci_lower = pred_summary['mean_ci_lower']
        ci_upper = pred_summary['mean_ci_upper']

        # Scatter plot
        fig.add_trace(
            go.Scatter(
                x=data['age'],
                y=data[ratio_name],
                mode='markers',
                marker=dict(color=color, size=11, symbol='circle', opacity=0.8),
                showlegend=False
            ),
            row=row_idx, col=1
        )

        # Fit line
        fig.add_trace(
            go.Scatter(
                x=x_range,
                y=y_fit,
                mode='lines',
                line=dict(color=color, width=2, dash='solid'),
                showlegend=False
            ),
            row=row_idx, col=1
        )

        # Confidence interval
        fig.add_trace(
            go.Scatter(
                x=np.concatenate([x_range, x_range[::-1]]),
                y=np.concatenate([ci_upper, ci_lower[::-1]]),
                fill='toself',
                fillcolor=ci_color,
                line=dict(color='rgba(255,255,255,0)'),
                hoverinfo='skip',
                showlegend=False,
            ),
            row=row_idx, col=1
        )

        # Add p-value as annotation
        p_value = ols_results.pvalues['age']
        significance = ''
        if p_value < 0.05:
            significance = '*'
            font_color='red'
        else:
            font_color='black'
            
        fig.add_annotation(
            x=0.9,  # relative within subplot (0–1)
            y=0.98,  # near the top
            xref="x domain",
            yref="y domain",
            text = f'p-Age = {p_value:.3f} <span style="color:{font_color}">{significance}</span>',
            showarrow=False,
            font=dict(family='Arial', size=16, color='black'),
            bgcolor='rgba(255, 255, 255, 0.7)',
            bordercolor='black',
            borderwidth=1,
            borderpad=4,
            row=row_idx, col=1
        )

        fig.update_xaxes(
                title_text='Age',
                title_font=dict(family='Arial', size=20, color='black', weight='bold'),
                tickfont=dict(family='Arial', size=18),
                tickvals=list(range(6, 18)),
                range=[5, 18],
                row=row_idx, col=1
            )
        
        fig.update_yaxes(
                title_text=f'{label_1}/{label_2} CSA ratio in C{vert}',
                title_font=dict(family='Arial', size=20, color='black', weight='bold'),
                tickfont=dict(family='Arial', size=18),
                range=[y_min, y_max],
                row=row_idx, col=1
            )

    # Update layout
    fig.update_layout(
        height=1800,
        width=525,
        plot_bgcolor="#ffffff",
        paper_bgcolor="#ffffff"
    )

    fig.show()

# %% [markdown]
# ## Plot GM / SC CSA ratio vs Age

# %%
plot_ratio(df_GM_WM_SC, 'GM', 'SC', 0.125, 0.275)
# Out:
#             Timestamp_WM  SCT Version_WM  \
# 5    2026-07-09 23:05:21             7.1
# 11   2026-07-09 23:06:17             7.1
# 17   2026-07-09 23:04:26             7.1
# 18   2026-07-09 23:04:26             7.1
# 24   2026-07-09 23:05:04             7.1
# ..                   ...             ...
# 380  2026-07-09 23:05:34             7.1
# 383  2026-07-09 23:05:22             7.1
# 388  2026-07-09 23:06:17             7.1
# 399  2026-07-09 23:05:07             7.1
# 405  2026-07-09 23:05:31             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 5    /Users/samuellestonge/Documents/datasets/phila...           10:12
# 11   /Users/samuellestonge/Documents/datasets/phila...           11:13
# 17   /Users/samuellestonge/Documents/datasets/phila...           12:14
# 18   /Users/samuellestonge/Documents/datasets/phila...           11:14
# 24   /Users/samuellestonge/Documents/datasets/phila...           13:14
# ..                                                 ...             ...
# 380  /Users/samuellestonge/Documents/datasets/phila...           10:12
# 383  /Users/samuellestonge/Documents/datasets/phila...           11:13
# 388  /Users/samuellestonge/Documents/datasets/phila...            9:13
# 399  /Users/samuellestonge/Documents/datasets/phila...           12:14
# 405  /Users/samuellestonge/Documents/datasets/phila...            8:11
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 5             NaN             NaN      59.523449      0.960178
# 11            NaN             NaN      60.567087      2.208685
# 17            NaN             NaN      54.537264      4.027795
# 18            NaN             NaN      51.048281      2.750562
# 24            NaN             NaN      63.254317      3.036252
# ..            ...             ...            ...           ...
# 380           NaN             NaN      57.854535      1.788361
# 383           NaN             NaN      59.478389      0.463983
# 388           NaN             NaN      60.308896      3.504808
# 399           NaN             NaN      56.526345      0.742415
# 405           NaN             NaN      51.122661      1.031887
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 5            -1.166573          0.179585  ...       15.035664   control
# 11            0.574448          0.306361  ...       15.123789   control
# 17            3.277571          0.480251  ...       15.206685   control
# 18           -4.152304          0.787842  ...       20.148369   control
# 24           -1.037004          0.005484  ...       10.180364   control
# ..                 ...               ...  ...             ...       ...
# 380          -0.125454          0.103576  ...       15.148168   control
# 383           8.207483          0.182700  ...       15.280265   control
# 388           2.505784          1.341970  ...       25.585408   control
# 399          -0.194259          0.074184  ...       15.147575   control
# 405           2.711901          0.222513  ...       20.124046   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 5          complete     1.6002  81.193034     0.208113     0.172261
# 11         complete     1.5240  45.359237     0.211436     0.174497
# 17         complete     1.6764  61.234970     0.216251     0.177873
# 18         complete     1.6510  54.431084     0.223945     0.183026
# 24         complete     1.6002  45.359237     0.179903     0.152713
# ..              ...        ...        ...          ...          ...
# 380      incomplete     1.3716  40.823313     0.215225     0.177128
# 383        complete     1.6510  65.770894     0.208383     0.172371
# 388        complete     1.3716  22.679619     0.205149     0.170249
# 399      incomplete     1.3970  36.287390     0.222472     0.182038
# 405        complete     1.4224  29.211349     0.208755     0.172682
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 5        17.226126     0.827730      82.772986
# 11       17.449698     0.825295      82.529534
# 17       17.787274     0.822528      82.252798
# 18       18.302606     0.817280      81.727999
# 24       15.271336     0.848863      84.886347
# ..             ...          ...            ...
# 380      17.712811     0.822989      82.298913
# 383      17.237083     0.827182      82.718210
# 388      17.024877     0.829879      82.987871
# 399      18.203796     0.818250      81.824954
# 405      17.268172     0.827199      82.719878
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_SC_ratio   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     10.96
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):            0.00152
# Time:                        00:02:08   Log-Likelihood:                 188.59
# No. Observations:                  67   AIC:                            -373.2
# Df Residuals:                      65   BIC:                            -368.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2076      0.009     23.467      0.000       0.190       0.225
# age           -0.0022      0.001     -3.311      0.002      -0.004      -0.001
# ==============================================================================
# Omnibus:                       10.487   Durbin-Watson:                   1.455
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.352
# Skew:                           0.882   Prob(JB):                      0.00565
# Kurtosis:                       3.771   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 4    2026-07-09 23:05:23             7.1
# 10   2026-07-09 23:06:19             7.1
# 15   2026-07-09 23:04:28             7.1
# 21   2026-07-09 23:04:28             7.1
# 25   2026-07-09 23:05:06             7.1
# ..                   ...             ...
# 376  2026-07-09 23:05:36             7.1
# 386  2026-07-09 23:05:23             7.1
# 393  2026-07-09 23:06:19             7.1
# 397  2026-07-09 23:05:09             7.1
# 404  2026-07-09 23:05:33             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 4    /Users/samuellestonge/Documents/datasets/phila...             8:9
# 10   /Users/samuellestonge/Documents/datasets/phila...            8:10
# 15   /Users/samuellestonge/Documents/datasets/phila...            9:11
# 21   /Users/samuellestonge/Documents/datasets/phila...            8:10
# 25   /Users/samuellestonge/Documents/datasets/phila...           10:12
# ..                                                 ...             ...
# 376  /Users/samuellestonge/Documents/datasets/phila...             8:9
# 386  /Users/samuellestonge/Documents/datasets/phila...            8:10
# 393  /Users/samuellestonge/Documents/datasets/phila...               8
# 397  /Users/samuellestonge/Documents/datasets/phila...           10:11
# 404  /Users/samuellestonge/Documents/datasets/phila...             6:7
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 4             NaN             NaN      60.227878      0.260861
# 10            NaN             NaN      54.854543      1.305650
# 15            NaN             NaN      57.252902      3.654014
# 21            NaN             NaN      47.438782      1.835056
# 25            NaN             NaN      61.268959      1.965815
# ..            ...             ...            ...           ...
# 376           NaN             NaN      55.939351      2.319029
# 386           NaN             NaN      54.822356      1.491608
# 393           NaN             NaN      55.671147      0.000000
# 397           NaN             NaN      55.420332      2.029799
# 404           NaN             NaN      56.028857      0.466785
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 4            -0.702973          0.073091  ...       10.003936   control
# 10           -0.721812          0.399416  ...       15.087004   control
# 15            1.951061          0.243185  ...       15.046978   control
# 21           -2.211707          0.318964  ...       15.019901   control
# 25           -0.963584          0.037268  ...       15.057403   control
# ..                 ...               ...  ...             ...       ...
# 376          -0.339409          0.019438  ...       10.058584   control
# 386           7.383401          0.266287  ...       15.161974   control
# 393           4.782581          0.000000  ...        5.126682   control
# 397           0.013025          0.036930  ...       10.061209   control
# 404           2.966345          0.026762  ...       10.039870   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 4          complete     1.6002  81.193034     0.250947     0.200596
# 10         complete     1.5240  45.359237     0.262738     0.208065
# 15         complete     1.6764  61.234970     0.253907     0.202502
# 21         complete     1.6510  54.431084     0.224628     0.183437
# 25         complete     1.6002  45.359237     0.215802     0.177556
# ..              ...        ...        ...          ...          ...
# 376      incomplete     1.3716  40.823313     0.241891     0.194745
# 386        complete     1.6510  65.770894     0.244641     0.196482
# 393        complete     1.3716  22.679619     0.157664     0.136202
# 397      incomplete     1.3970  36.287390     0.266596     0.210485
# 404        complete     1.4224  29.211349     0.226626     0.184757
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 4        20.059550     0.799355      79.935485
# 10       20.806467     0.791908      79.190819
# 15       20.250201     0.797543      79.754269
# 21       18.343720     0.816626      81.662647
# 25       17.755618     0.822772      82.277217
# ..             ...          ...            ...
# 376      19.474506     0.805093      80.509266
# 386      19.648203     0.803144      80.314351
# 393      13.620155     0.863871      86.387068
# 397      21.048478     0.789526      78.952594
# 404      18.475715     0.815250      81.525037
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_SC_ratio   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     3.369
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):             0.0710
# Time:                        00:02:08   Log-Likelihood:                 170.00
# No. Observations:                  67   AIC:                            -336.0
# Df Residuals:                      65   BIC:                            -331.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2170      0.012     18.595      0.000       0.194       0.240
# age           -0.0016      0.001     -1.836      0.071      -0.003       0.000
# ==============================================================================
# Omnibus:                        5.894   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                8.324
# Skew:                          -0.183   Prob(JB):                       0.0156
# Kurtosis:                       4.688   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 3    2026-07-09 23:05:25             7.1
# 8    2026-07-09 23:06:21             7.1
# 14   2026-07-09 23:04:30             7.1
# 20   2026-07-09 23:04:29             7.1
# 27   2026-07-09 23:05:08             7.1
# ..                   ...             ...
# 377  2026-07-09 23:05:38             7.1
# 387  2026-07-09 23:05:25             7.1
# 392  2026-07-09 23:06:22             7.1
# 398  2026-07-09 23:05:11             7.1
# 402  2026-07-09 23:05:35             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 3    /Users/samuellestonge/Documents/datasets/phila...             5:7
# 8    /Users/samuellestonge/Documents/datasets/phila...             6:7
# 14   /Users/samuellestonge/Documents/datasets/phila...             6:8
# 20   /Users/samuellestonge/Documents/datasets/phila...             5:7
# 27   /Users/samuellestonge/Documents/datasets/phila...             7:9
# ..                                                 ...             ...
# 377  /Users/samuellestonge/Documents/datasets/phila...             5:7
# 387  /Users/samuellestonge/Documents/datasets/phila...             5:7
# 392  /Users/samuellestonge/Documents/datasets/phila...             6:7
# 398  /Users/samuellestonge/Documents/datasets/phila...             8:9
# 402  /Users/samuellestonge/Documents/datasets/phila...             3:5
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 3             NaN             NaN      58.827611      1.698180
# 8             NaN             NaN      55.804004      0.768079
# 14            NaN             NaN      58.387201      0.968191
# 20            NaN             NaN      53.728778      5.204125
# 27            NaN             NaN      66.298396      1.850538
# ..            ...             ...            ...           ...
# 377           NaN             NaN      60.104501      3.799112
# 387           NaN             NaN      60.290770      2.124967
# 392           NaN             NaN      53.860084      4.681662
# 398           NaN             NaN      56.940832      0.339244
# 402           NaN             NaN      59.579088      1.441259
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 3            -0.435720          0.059625  ...       15.001372   control
# 8            -2.054715          0.291721  ...       10.035984   control
# 14            1.499857          0.023234  ...       15.008673   control
# 20           -1.449031          0.099133  ...       15.005932   control
# 27           -0.765064          0.071011  ...       15.007817   control
# ..                 ...               ...  ...             ...       ...
# 377          -0.319838          0.040607  ...       15.015595   control
# 387           6.250311          0.350830  ...       15.092876   control
# 392           5.288535          0.116256  ...       10.191633   control
# 398           0.147164          0.030139  ...       10.033874   control
# 402           2.555740          0.214142  ...       15.022596   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 3          complete     1.6002  81.193034     0.269127     0.212057
# 8          complete     1.5240  45.359237     0.218759     0.179511
# 14         complete     1.6764  61.234970     0.283850     0.221104
# 20         complete     1.6510  54.431084     0.266717     0.210567
# 27         complete     1.6002  45.359237     0.254929     0.203126
# ..              ...        ...        ...          ...          ...
# 377      incomplete     1.3716  40.823313     0.267256     0.210893
# 387        complete     1.6510  65.770894     0.280182     0.218829
# 392        complete     1.3716  22.679619     0.232317     0.188483
# 398      incomplete     1.3970  36.287390     0.268715     0.211763
# 402        complete     1.4224  29.211349     0.254167     0.202664
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 3        21.205655     0.787943      78.794290
# 8        17.951094     0.820590      82.058954
# 14       22.110414     0.778946      77.894605
# 20       21.056667     0.789476      78.947593
# 27       20.312590     0.796796      79.679554
# ..             ...          ...            ...
# 377      21.089251     0.789103      78.910280
# 387      21.882937     0.781026      78.102554
# 392      18.848335     0.811320      81.131984
# 398      21.176301     0.788059      78.805856
# 402      20.266437     0.797367      79.736709
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_SC_ratio   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.3570
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.552
# Time:                        00:02:08   Log-Likelihood:                 177.11
# No. Observations:                  67   AIC:                            -350.2
# Df Residuals:                      65   BIC:                            -345.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2156      0.010     20.542      0.000       0.195       0.237
# age           -0.0005      0.001     -0.597      0.552      -0.002       0.001
# ==============================================================================
# Omnibus:                        3.875   Durbin-Watson:                   2.549
# Prob(Omnibus):                  0.144   Jarque-Bera (JB):                3.001
# Skew:                          -0.408   Prob(JB):                        0.223
# Kurtosis:                       3.641   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 0    2026-07-09 23:05:27             7.1
# 6    2026-07-09 23:06:23             7.1
# 12   2026-07-09 23:04:32             7.1
# 22   2026-07-09 23:04:31             7.1
# 29   2026-07-09 23:05:10             7.1
# ..                   ...             ...
# 379  2026-07-09 23:05:40             7.1
# 385  2026-07-09 23:05:27             7.1
# 389  2026-07-09 23:06:24             7.1
# 395  2026-07-09 23:05:13             7.1
# 400  2026-07-09 23:05:37             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 0    /Users/samuellestonge/Documents/datasets/phila...             2:4
# 6    /Users/samuellestonge/Documents/datasets/phila...             3:5
# 12   /Users/samuellestonge/Documents/datasets/phila...             3:5
# 22   /Users/samuellestonge/Documents/datasets/phila...             2:4
# 29   /Users/samuellestonge/Documents/datasets/phila...             4:6
# ..                                                 ...             ...
# 379  /Users/samuellestonge/Documents/datasets/phila...             3:4
# 385  /Users/samuellestonge/Documents/datasets/phila...             3:4
# 389  /Users/samuellestonge/Documents/datasets/phila...             4:5
# 395  /Users/samuellestonge/Documents/datasets/phila...             6:7
# 400  /Users/samuellestonge/Documents/datasets/phila...               2
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 0             NaN             NaN      61.300003      4.364803
# 6             NaN             NaN      60.667879      1.829342
# 12            NaN             NaN      61.028212      2.451873
# 22            NaN             NaN      55.533542      0.952749
# 29            NaN             NaN      69.685819      3.818387
# ..            ...             ...            ...           ...
# 379           NaN             NaN      63.835640      2.393353
# 385           NaN             NaN      61.500179      1.224447
# 389           NaN             NaN      53.390303      1.976926
# 395           NaN             NaN      53.934173      2.725247
# 400           NaN             NaN      65.437941      0.000000
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 0            -0.350735          0.014703  ...       15.008764   control
# 6            -3.637636          0.552403  ...       15.042813   control
# 12            1.925671          0.236313  ...       15.035331   control
# 22           -1.500651          0.126713  ...       15.013539   control
# 29           -0.442299          0.104806  ...       15.051669   control
# ..                 ...               ...  ...             ...       ...
# 379          -0.095931          0.068135  ...       10.150004   control
# 385           5.074871          0.258342  ...       10.039656   control
# 389           5.439926          0.040531  ...       10.089948   control
# 395           0.254139          0.023348  ...       10.012557   control
# 400           1.894732          0.000000  ...        5.004841   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 0          complete     1.6002  81.193034     0.275756     0.216149
# 6          complete     1.5240  45.359237     0.165746     0.142198
# 12         complete     1.6764  61.234970     0.269716     0.212429
# 22         complete     1.6510  54.431084     0.286308     0.222575
# 29         complete     1.6002  45.359237     0.243908     0.196017
# ..              ...        ...        ...          ...          ...
# 379      incomplete     1.3716  40.823313     0.279110     0.218094
# 385        complete     1.6510  65.770894     0.273532     0.214809
# 389        complete     1.3716  22.679619     0.260078     0.206415
# 395      incomplete     1.3970  36.287390     0.289046     0.224192
# 400        complete     1.4224  29.211349     0.225196     0.183809
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 0        21.614861     0.783840      78.384000
# 6        14.219818     0.857929      85.792912
# 12       21.242868     0.787602      78.760237
# 22       22.257463     0.777396      77.739619
# 29       19.601689     0.803652      80.365167
# ..             ...          ...            ...
# 379      21.809417     0.781393      78.139263
# 385      21.480886     0.785316      78.531618
# 389      20.641472     0.793666      79.366597
# 395      22.419152     0.775627      77.562680
# 400      18.380855     0.816216      81.621590
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_SC_ratio   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     3.602
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):             0.0622
# Time:                        00:02:08   Log-Likelihood:                 177.77
# No. Observations:                  67   AIC:                            -351.5
# Df Residuals:                      65   BIC:                            -347.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2292      0.010     22.050      0.000       0.208       0.250
# age           -0.0015      0.001     -1.898      0.062      -0.003    7.71e-05
# ==============================================================================
# Omnibus:                       15.204   Durbin-Watson:                   2.316
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.766
# Skew:                          -0.622   Prob(JB):                     2.82e-08
# Kurtosis:                       6.303   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 1    2026-07-09 23:05:29             7.1
# 7    2026-07-09 23:06:26             7.1
# 13   2026-07-09 23:04:34             7.1
# 23   2026-07-09 23:04:33             7.1
# 28   2026-07-09 23:05:12             7.1
# ..                   ...             ...
# 378  2026-07-09 23:05:42             7.1
# 384  2026-07-09 23:05:29             7.1
# 390  2026-07-09 23:06:26             7.1
# 394  2026-07-09 23:05:15             7.1
# 401  2026-07-09 23:05:39             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 1    /Users/samuellestonge/Documents/datasets/phila...             0:1
# 7    /Users/samuellestonge/Documents/datasets/phila...             1:2
# 13   /Users/samuellestonge/Documents/datasets/phila...             1:2
# 23   /Users/samuellestonge/Documents/datasets/phila...             0:1
# 28   /Users/samuellestonge/Documents/datasets/phila...             1:3
# ..                                                 ...             ...
# 378  /Users/samuellestonge/Documents/datasets/phila...             1:2
# 384  /Users/samuellestonge/Documents/datasets/phila...             0:2
# 390  /Users/samuellestonge/Documents/datasets/phila...             1:3
# 394  /Users/samuellestonge/Documents/datasets/phila...             4:5
# 401  /Users/samuellestonge/Documents/datasets/phila...             0:1
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 1             NaN             NaN      62.816458      0.877176
# 7             NaN             NaN      64.440374      2.046984
# 13            NaN             NaN      61.574490      0.904916
# 23            NaN             NaN      56.783374      3.878101
# 28            NaN             NaN      59.603193      5.896786
# ..            ...             ...            ...           ...
# 378           NaN             NaN      59.094982      4.734578
# 384           NaN             NaN      58.003858      3.366412
# 390           NaN             NaN      53.946520      2.650700
# 394           NaN             NaN      51.117388      0.618817
# 401           NaN             NaN      59.564615      1.807090
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 1            -0.476359          0.044769  ...       10.010993   control
# 7            -5.435259          0.383666  ...       10.051628   control
# 13            2.929284          0.265426  ...       10.052600   control
# 23           -2.146863          0.189495  ...       10.016782   control
# 28            0.004730          0.138613  ...       15.088900   control
# ..                 ...               ...  ...             ...       ...
# 378           0.246666          0.103163  ...       10.626136   control
# 384           3.666362          0.493492  ...       15.041644   control
# 390           4.713791          0.388781  ...       15.108131   control
# 394           0.333950          0.016558  ...       10.001366   control
# 401           1.149085          0.276341  ...       10.032520   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 1          complete     1.6002  81.193034     0.253924     0.202449
# 7          complete     1.5240  45.359237     0.221588     0.181396
# 13         complete     1.6764  61.234970     0.267835     0.211157
# 23         complete     1.6510  54.431084     0.274311     0.215204
# 28         complete     1.6002  45.359237     0.282122     0.219917
# ..              ...        ...        ...          ...          ...
# 378      incomplete     1.3716  40.823313     0.237900     0.192629
# 384        complete     1.6510  65.770894     0.293922     0.227192
# 390        complete     1.3716  22.679619     0.217911     0.178951
# 394      incomplete     1.3970  36.287390     0.293353     0.226805
# 401        complete     1.4224  29.211349     0.242742     0.195361
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 1        20.244878     0.797282      79.728152
# 7        18.139639     0.818619      81.861938
# 13       21.115716     0.788386      78.838558
# 23       21.520393     0.784527      78.452665
# 28       21.991665     0.779509      77.950905
# ..             ...          ...            ...
# 378      19.262906     0.809708      80.970761
# 384      22.719240     0.772967      77.296722
# 390      17.895126     0.821211      82.121092
# 394      22.680549     0.773149      77.314861
# 401      19.536141     0.804811      80.481071
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_SC_ratio   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9547
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.332
# Time:                        00:02:08   Log-Likelihood:                 175.65
# No. Observations:                  67   AIC:                            -347.3
# Df Residuals:                      65   BIC:                            -342.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1957      0.011     18.241      0.000       0.174       0.217
# age            0.0008      0.001      0.977      0.332      -0.001       0.002
# ==============================================================================
# Omnibus:                        3.430   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.180   Jarque-Bera (JB):                2.661
# Skew:                          -0.323   Prob(JB):                        0.264
# Kurtosis:                       3.732   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 2    2026-07-09 23:05:31             7.1
# 9    2026-07-09 23:06:28             7.1
# 16   2026-07-09 23:04:36             7.1
# 19   2026-07-09 23:04:35             7.1
# 26   2026-07-09 23:05:14             7.1
# ..                   ...             ...
# 381  2026-07-09 23:05:44             7.1
# 382  2026-07-09 23:05:31             7.1
# 391  2026-07-09 23:06:28             7.1
# 396  2026-07-09 23:05:17             7.1
# 403  2026-07-09 23:05:41             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 2    /Users/samuellestonge/Documents/datasets/phila...            0:12
# 9    /Users/samuellestonge/Documents/datasets/phila...            1:13
# 16   /Users/samuellestonge/Documents/datasets/phila...            1:14
# 19   /Users/samuellestonge/Documents/datasets/phila...            0:14
# 26   /Users/samuellestonge/Documents/datasets/phila...            1:14
# ..                                                 ...             ...
# 381  /Users/samuellestonge/Documents/datasets/phila...            1:12
# 382  /Users/samuellestonge/Documents/datasets/phila...            0:13
# 391  /Users/samuellestonge/Documents/datasets/phila...            1:13
# 396  /Users/samuellestonge/Documents/datasets/phila...            4:14
# 403  /Users/samuellestonge/Documents/datasets/phila...            0:11
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 2             NaN             NaN      60.387836      2.690938
# 9             NaN             NaN      59.135176      3.782576
# 16            NaN             NaN      58.340409      3.786702
# 19            NaN             NaN      52.524212      4.535168
# 26            NaN             NaN      64.076981      5.227640
# ..            ...             ...            ...           ...
# 381           NaN             NaN      59.301421      3.999633
# 382           NaN             NaN      58.627606      3.040722
# 391           NaN             NaN      56.427382      4.473390
# 396           NaN             NaN      54.945862      2.576273
# 403           NaN             NaN      56.654399      4.658251
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 2            -0.632134          0.327167  ...       65.060729   control
# 9            -2.025765          2.122585  ...       65.341217   control
# 16            2.272932          0.733602  ...       70.350267   control
# 19           -2.425807          1.171432  ...       75.204523   control
# 26           -0.612333          0.390950  ...       70.386154   control
# ..                 ...               ...  ...             ...       ...
# 381          -0.142769          0.213787  ...       60.998487   control
# 382           6.190887          1.682551  ...       70.616414   control
# 391           4.069984          1.524070  ...       66.101802   control
# 396           0.083071          0.203574  ...       55.256581   control
# 403           2.386701          0.643941  ...       60.223873   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 2          complete     1.6002  81.193034     0.251579     0.200998
# 9          complete     1.5240  45.359237     0.214366     0.176523
# 16         complete     1.6764  61.234970     0.258429     0.205366
# 19         complete     1.6510  54.431084     0.253266     0.202095
# 26         complete     1.6002  45.359237     0.239183     0.193029
# ..              ...        ...        ...          ...          ...
# 381      incomplete     1.3716  40.823313     0.247829     0.198666
# 382        complete     1.6510  65.770894     0.259368     0.205921
# 391        complete     1.3716  22.679619     0.216346     0.177879
# 396      incomplete     1.3970  36.287390     0.263148     0.208328
# 403        complete     1.4224  29.211349     0.231178     0.187771
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 2        20.099786     0.798946      79.894647
# 9        17.652340     0.823468      82.346781
# 16       20.536586     0.794670      79.466957
# 19       20.209535     0.797956      79.795631
# 26       19.302931     0.807034      80.703438
# ..             ...          ...            ...
# 381      19.866588     0.801625      80.162512
# 382      20.592091     0.793933      79.393283
# 391      17.787914     0.822197      82.219670
# 396      20.832821     0.791677      79.167699
# 403      18.777087     0.812236      81.223628
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_SC_ratio   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     3.574
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):             0.0631
# Time:                        00:02:08   Log-Likelihood:                 207.42
# No. Observations:                  67   AIC:                            -410.8
# Df Residuals:                      65   BIC:                            -406.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2123      0.007     31.803      0.000       0.199       0.226
# age           -0.0009      0.000     -1.891      0.063      -0.002    5.32e-05
# ==============================================================================
# Omnibus:                        0.252   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.881   Jarque-Bera (JB):                0.188
# Skew:                          -0.124   Prob(JB):                        0.910
# Kurtosis:                       2.921   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Plot WM / SC CSA ratio vs Age

# %%
plot_ratio(df_GM_WM_SC, 'WM', 'SC', 0.75, 0.85)
# Out:
#             Timestamp_WM  SCT Version_WM  \
# 5    2026-07-09 23:05:21             7.1
# 11   2026-07-09 23:06:17             7.1
# 17   2026-07-09 23:04:26             7.1
# 18   2026-07-09 23:04:26             7.1
# 24   2026-07-09 23:05:04             7.1
# ..                   ...             ...
# 380  2026-07-09 23:05:34             7.1
# 383  2026-07-09 23:05:22             7.1
# 388  2026-07-09 23:06:17             7.1
# 399  2026-07-09 23:05:07             7.1
# 405  2026-07-09 23:05:31             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 5    /Users/samuellestonge/Documents/datasets/phila...           10:12
# 11   /Users/samuellestonge/Documents/datasets/phila...           11:13
# 17   /Users/samuellestonge/Documents/datasets/phila...           12:14
# 18   /Users/samuellestonge/Documents/datasets/phila...           11:14
# 24   /Users/samuellestonge/Documents/datasets/phila...           13:14
# ..                                                 ...             ...
# 380  /Users/samuellestonge/Documents/datasets/phila...           10:12
# 383  /Users/samuellestonge/Documents/datasets/phila...           11:13
# 388  /Users/samuellestonge/Documents/datasets/phila...            9:13
# 399  /Users/samuellestonge/Documents/datasets/phila...           12:14
# 405  /Users/samuellestonge/Documents/datasets/phila...            8:11
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 5             NaN             NaN      59.523449      0.960178
# 11            NaN             NaN      60.567087      2.208685
# 17            NaN             NaN      54.537264      4.027795
# 18            NaN             NaN      51.048281      2.750562
# 24            NaN             NaN      63.254317      3.036252
# ..            ...             ...            ...           ...
# 380           NaN             NaN      57.854535      1.788361
# 383           NaN             NaN      59.478389      0.463983
# 388           NaN             NaN      60.308896      3.504808
# 399           NaN             NaN      56.526345      0.742415
# 405           NaN             NaN      51.122661      1.031887
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 5            -1.166573          0.179585  ...       15.035664   control
# 11            0.574448          0.306361  ...       15.123789   control
# 17            3.277571          0.480251  ...       15.206685   control
# 18           -4.152304          0.787842  ...       20.148369   control
# 24           -1.037004          0.005484  ...       10.180364   control
# ..                 ...               ...  ...             ...       ...
# 380          -0.125454          0.103576  ...       15.148168   control
# 383           8.207483          0.182700  ...       15.280265   control
# 388           2.505784          1.341970  ...       25.585408   control
# 399          -0.194259          0.074184  ...       15.147575   control
# 405           2.711901          0.222513  ...       20.124046   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 5          complete     1.6002  81.193034     0.208113     0.172261
# 11         complete     1.5240  45.359237     0.211436     0.174497
# 17         complete     1.6764  61.234970     0.216251     0.177873
# 18         complete     1.6510  54.431084     0.223945     0.183026
# 24         complete     1.6002  45.359237     0.179903     0.152713
# ..              ...        ...        ...          ...          ...
# 380      incomplete     1.3716  40.823313     0.215225     0.177128
# 383        complete     1.6510  65.770894     0.208383     0.172371
# 388        complete     1.3716  22.679619     0.205149     0.170249
# 399      incomplete     1.3970  36.287390     0.222472     0.182038
# 405        complete     1.4224  29.211349     0.208755     0.172682
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 5        17.226126     0.827730      82.772986
# 11       17.449698     0.825295      82.529534
# 17       17.787274     0.822528      82.252798
# 18       18.302606     0.817280      81.727999
# 24       15.271336     0.848863      84.886347
# ..             ...          ...            ...
# 380      17.712811     0.822989      82.298913
# 383      17.237083     0.827182      82.718210
# 388      17.024877     0.829879      82.987871
# 399      18.203796     0.818250      81.824954
# 405      17.268172     0.827199      82.719878
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            WM_SC_ratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                   0.01144
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.915
# Time:                        00:02:08   Log-Likelihood:                 130.68
# No. Observations:                  67   AIC:                            -257.4
# Df Residuals:                      65   BIC:                            -252.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8293      0.021     39.507      0.000       0.787       0.871
# age           -0.0002      0.002     -0.107      0.915      -0.003       0.003
# ==============================================================================
# Omnibus:                       96.667   Durbin-Watson:                   2.248
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1842.946
# Skew:                           4.337   Prob(JB):                         0.00
# Kurtosis:                      27.185   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 4    2026-07-09 23:05:23             7.1
# 10   2026-07-09 23:06:19             7.1
# 15   2026-07-09 23:04:28             7.1
# 21   2026-07-09 23:04:28             7.1
# 25   2026-07-09 23:05:06             7.1
# ..                   ...             ...
# 376  2026-07-09 23:05:36             7.1
# 386  2026-07-09 23:05:23             7.1
# 393  2026-07-09 23:06:19             7.1
# 397  2026-07-09 23:05:09             7.1
# 404  2026-07-09 23:05:33             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 4    /Users/samuellestonge/Documents/datasets/phila...             8:9
# 10   /Users/samuellestonge/Documents/datasets/phila...            8:10
# 15   /Users/samuellestonge/Documents/datasets/phila...            9:11
# 21   /Users/samuellestonge/Documents/datasets/phila...            8:10
# 25   /Users/samuellestonge/Documents/datasets/phila...           10:12
# ..                                                 ...             ...
# 376  /Users/samuellestonge/Documents/datasets/phila...             8:9
# 386  /Users/samuellestonge/Documents/datasets/phila...            8:10
# 393  /Users/samuellestonge/Documents/datasets/phila...               8
# 397  /Users/samuellestonge/Documents/datasets/phila...           10:11
# 404  /Users/samuellestonge/Documents/datasets/phila...             6:7
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 4             NaN             NaN      60.227878      0.260861
# 10            NaN             NaN      54.854543      1.305650
# 15            NaN             NaN      57.252902      3.654014
# 21            NaN             NaN      47.438782      1.835056
# 25            NaN             NaN      61.268959      1.965815
# ..            ...             ...            ...           ...
# 376           NaN             NaN      55.939351      2.319029
# 386           NaN             NaN      54.822356      1.491608
# 393           NaN             NaN      55.671147      0.000000
# 397           NaN             NaN      55.420332      2.029799
# 404           NaN             NaN      56.028857      0.466785
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 4            -0.702973          0.073091  ...       10.003936   control
# 10           -0.721812          0.399416  ...       15.087004   control
# 15            1.951061          0.243185  ...       15.046978   control
# 21           -2.211707          0.318964  ...       15.019901   control
# 25           -0.963584          0.037268  ...       15.057403   control
# ..                 ...               ...  ...             ...       ...
# 376          -0.339409          0.019438  ...       10.058584   control
# 386           7.383401          0.266287  ...       15.161974   control
# 393           4.782581          0.000000  ...        5.126682   control
# 397           0.013025          0.036930  ...       10.061209   control
# 404           2.966345          0.026762  ...       10.039870   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 4          complete     1.6002  81.193034     0.250947     0.200596
# 10         complete     1.5240  45.359237     0.262738     0.208065
# 15         complete     1.6764  61.234970     0.253907     0.202502
# 21         complete     1.6510  54.431084     0.224628     0.183437
# 25         complete     1.6002  45.359237     0.215802     0.177556
# ..              ...        ...        ...          ...          ...
# 376      incomplete     1.3716  40.823313     0.241891     0.194745
# 386        complete     1.6510  65.770894     0.244641     0.196482
# 393        complete     1.3716  22.679619     0.157664     0.136202
# 397      incomplete     1.3970  36.287390     0.266596     0.210485
# 404        complete     1.4224  29.211349     0.226626     0.184757
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 4        20.059550     0.799355      79.935485
# 10       20.806467     0.791908      79.190819
# 15       20.250201     0.797543      79.754269
# 21       18.343720     0.816626      81.662647
# 25       17.755618     0.822772      82.277217
# ..             ...          ...            ...
# 376      19.474506     0.805093      80.509266
# 386      19.648203     0.803144      80.314351
# 393      13.620155     0.863871      86.387068
# 397      21.048478     0.789526      78.952594
# 404      18.475715     0.815250      81.525037
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            WM_SC_ratio   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.005
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.320
# Time:                        00:02:08   Log-Likelihood:                 116.03
# No. Observations:                  67   AIC:                            -228.1
# Df Residuals:                      65   BIC:                            -223.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7869      0.026     30.128      0.000       0.735       0.839
# age            0.0020      0.002      1.002      0.320      -0.002       0.006
# ==============================================================================
# Omnibus:                       75.169   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              628.279
# Skew:                           3.342   Prob(JB):                    3.72e-137
# Kurtosis:                      16.430   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 3    2026-07-09 23:05:25             7.1
# 8    2026-07-09 23:06:21             7.1
# 14   2026-07-09 23:04:30             7.1
# 20   2026-07-09 23:04:29             7.1
# 27   2026-07-09 23:05:08             7.1
# ..                   ...             ...
# 377  2026-07-09 23:05:38             7.1
# 387  2026-07-09 23:05:25             7.1
# 392  2026-07-09 23:06:22             7.1
# 398  2026-07-09 23:05:11             7.1
# 402  2026-07-09 23:05:35             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 3    /Users/samuellestonge/Documents/datasets/phila...             5:7
# 8    /Users/samuellestonge/Documents/datasets/phila...             6:7
# 14   /Users/samuellestonge/Documents/datasets/phila...             6:8
# 20   /Users/samuellestonge/Documents/datasets/phila...             5:7
# 27   /Users/samuellestonge/Documents/datasets/phila...             7:9
# ..                                                 ...             ...
# 377  /Users/samuellestonge/Documents/datasets/phila...             5:7
# 387  /Users/samuellestonge/Documents/datasets/phila...             5:7
# 392  /Users/samuellestonge/Documents/datasets/phila...             6:7
# 398  /Users/samuellestonge/Documents/datasets/phila...             8:9
# 402  /Users/samuellestonge/Documents/datasets/phila...             3:5
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 3             NaN             NaN      58.827611      1.698180
# 8             NaN             NaN      55.804004      0.768079
# 14            NaN             NaN      58.387201      0.968191
# 20            NaN             NaN      53.728778      5.204125
# 27            NaN             NaN      66.298396      1.850538
# ..            ...             ...            ...           ...
# 377           NaN             NaN      60.104501      3.799112
# 387           NaN             NaN      60.290770      2.124967
# 392           NaN             NaN      53.860084      4.681662
# 398           NaN             NaN      56.940832      0.339244
# 402           NaN             NaN      59.579088      1.441259
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 3            -0.435720          0.059625  ...       15.001372   control
# 8            -2.054715          0.291721  ...       10.035984   control
# 14            1.499857          0.023234  ...       15.008673   control
# 20           -1.449031          0.099133  ...       15.005932   control
# 27           -0.765064          0.071011  ...       15.007817   control
# ..                 ...               ...  ...             ...       ...
# 377          -0.319838          0.040607  ...       15.015595   control
# 387           6.250311          0.350830  ...       15.092876   control
# 392           5.288535          0.116256  ...       10.191633   control
# 398           0.147164          0.030139  ...       10.033874   control
# 402           2.555740          0.214142  ...       15.022596   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 3          complete     1.6002  81.193034     0.269127     0.212057
# 8          complete     1.5240  45.359237     0.218759     0.179511
# 14         complete     1.6764  61.234970     0.283850     0.221104
# 20         complete     1.6510  54.431084     0.266717     0.210567
# 27         complete     1.6002  45.359237     0.254929     0.203126
# ..              ...        ...        ...          ...          ...
# 377      incomplete     1.3716  40.823313     0.267256     0.210893
# 387        complete     1.6510  65.770894     0.280182     0.218829
# 392        complete     1.3716  22.679619     0.232317     0.188483
# 398      incomplete     1.3970  36.287390     0.268715     0.211763
# 402        complete     1.4224  29.211349     0.254167     0.202664
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 3        21.205655     0.787943      78.794290
# 8        17.951094     0.820590      82.058954
# 14       22.110414     0.778946      77.894605
# 20       21.056667     0.789476      78.947593
# 27       20.312590     0.796796      79.679554
# ..             ...          ...            ...
# 377      21.089251     0.789103      78.910280
# 387      21.882937     0.781026      78.102554
# 392      18.848335     0.811320      81.131984
# 398      21.176301     0.788059      78.805856
# 402      20.266437     0.797367      79.736709
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            WM_SC_ratio   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.1066
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.745
# Time:                        00:02:08   Log-Likelihood:                 145.59
# No. Observations:                  67   AIC:                            -287.2
# Df Residuals:                      65   BIC:                            -282.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7885      0.017     46.930      0.000       0.755       0.822
# age            0.0004      0.001      0.327      0.745      -0.002       0.003
# ==============================================================================
# Omnibus:                       77.484   Durbin-Watson:                   2.366
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              899.132
# Skew:                           3.274   Prob(JB):                    5.70e-196
# Kurtosis:                      19.710   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 0    2026-07-09 23:05:27             7.1
# 6    2026-07-09 23:06:23             7.1
# 12   2026-07-09 23:04:32             7.1
# 22   2026-07-09 23:04:31             7.1
# 29   2026-07-09 23:05:10             7.1
# ..                   ...             ...
# 379  2026-07-09 23:05:40             7.1
# 385  2026-07-09 23:05:27             7.1
# 389  2026-07-09 23:06:24             7.1
# 395  2026-07-09 23:05:13             7.1
# 400  2026-07-09 23:05:37             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 0    /Users/samuellestonge/Documents/datasets/phila...             2:4
# 6    /Users/samuellestonge/Documents/datasets/phila...             3:5
# 12   /Users/samuellestonge/Documents/datasets/phila...             3:5
# 22   /Users/samuellestonge/Documents/datasets/phila...             2:4
# 29   /Users/samuellestonge/Documents/datasets/phila...             4:6
# ..                                                 ...             ...
# 379  /Users/samuellestonge/Documents/datasets/phila...             3:4
# 385  /Users/samuellestonge/Documents/datasets/phila...             3:4
# 389  /Users/samuellestonge/Documents/datasets/phila...             4:5
# 395  /Users/samuellestonge/Documents/datasets/phila...             6:7
# 400  /Users/samuellestonge/Documents/datasets/phila...               2
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 0             NaN             NaN      61.300003      4.364803
# 6             NaN             NaN      60.667879      1.829342
# 12            NaN             NaN      61.028212      2.451873
# 22            NaN             NaN      55.533542      0.952749
# 29            NaN             NaN      69.685819      3.818387
# ..            ...             ...            ...           ...
# 379           NaN             NaN      63.835640      2.393353
# 385           NaN             NaN      61.500179      1.224447
# 389           NaN             NaN      53.390303      1.976926
# 395           NaN             NaN      53.934173      2.725247
# 400           NaN             NaN      65.437941      0.000000
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 0            -0.350735          0.014703  ...       15.008764   control
# 6            -3.637636          0.552403  ...       15.042813   control
# 12            1.925671          0.236313  ...       15.035331   control
# 22           -1.500651          0.126713  ...       15.013539   control
# 29           -0.442299          0.104806  ...       15.051669   control
# ..                 ...               ...  ...             ...       ...
# 379          -0.095931          0.068135  ...       10.150004   control
# 385           5.074871          0.258342  ...       10.039656   control
# 389           5.439926          0.040531  ...       10.089948   control
# 395           0.254139          0.023348  ...       10.012557   control
# 400           1.894732          0.000000  ...        5.004841   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 0          complete     1.6002  81.193034     0.275756     0.216149
# 6          complete     1.5240  45.359237     0.165746     0.142198
# 12         complete     1.6764  61.234970     0.269716     0.212429
# 22         complete     1.6510  54.431084     0.286308     0.222575
# 29         complete     1.6002  45.359237     0.243908     0.196017
# ..              ...        ...        ...          ...          ...
# 379      incomplete     1.3716  40.823313     0.279110     0.218094
# 385        complete     1.6510  65.770894     0.273532     0.214809
# 389        complete     1.3716  22.679619     0.260078     0.206415
# 395      incomplete     1.3970  36.287390     0.289046     0.224192
# 400        complete     1.4224  29.211349     0.225196     0.183809
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 0        21.614861     0.783840      78.384000
# 6        14.219818     0.857929      85.792912
# 12       21.242868     0.787602      78.760237
# 22       22.257463     0.777396      77.739619
# 29       19.601689     0.803652      80.365167
# ..             ...          ...            ...
# 379      21.809417     0.781393      78.139263
# 385      21.480886     0.785316      78.531618
# 389      20.641472     0.793666      79.366597
# 395      22.419152     0.775627      77.562680
# 400      18.380855     0.816216      81.621590
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            WM_SC_ratio   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.4952
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.484
# Time:                        00:02:08   Log-Likelihood:                 165.15
# No. Observations:                  67   AIC:                            -326.3
# Df Residuals:                      65   BIC:                            -321.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7831      0.013     62.406      0.000       0.758       0.808
# age            0.0007      0.001      0.704      0.484      -0.001       0.003
# ==============================================================================
# Omnibus:                       35.445   Durbin-Watson:                   2.285
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.928
# Skew:                           1.491   Prob(JB):                     2.03e-27
# Kurtosis:                       8.928   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 1    2026-07-09 23:05:29             7.1
# 7    2026-07-09 23:06:26             7.1
# 13   2026-07-09 23:04:34             7.1
# 23   2026-07-09 23:04:33             7.1
# 28   2026-07-09 23:05:12             7.1
# ..                   ...             ...
# 378  2026-07-09 23:05:42             7.1
# 384  2026-07-09 23:05:29             7.1
# 390  2026-07-09 23:06:26             7.1
# 394  2026-07-09 23:05:15             7.1
# 401  2026-07-09 23:05:39             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 1    /Users/samuellestonge/Documents/datasets/phila...             0:1
# 7    /Users/samuellestonge/Documents/datasets/phila...             1:2
# 13   /Users/samuellestonge/Documents/datasets/phila...             1:2
# 23   /Users/samuellestonge/Documents/datasets/phila...             0:1
# 28   /Users/samuellestonge/Documents/datasets/phila...             1:3
# ..                                                 ...             ...
# 378  /Users/samuellestonge/Documents/datasets/phila...             1:2
# 384  /Users/samuellestonge/Documents/datasets/phila...             0:2
# 390  /Users/samuellestonge/Documents/datasets/phila...             1:3
# 394  /Users/samuellestonge/Documents/datasets/phila...             4:5
# 401  /Users/samuellestonge/Documents/datasets/phila...             0:1
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 1             NaN             NaN      62.816458      0.877176
# 7             NaN             NaN      64.440374      2.046984
# 13            NaN             NaN      61.574490      0.904916
# 23            NaN             NaN      56.783374      3.878101
# 28            NaN             NaN      59.603193      5.896786
# ..            ...             ...            ...           ...
# 378           NaN             NaN      59.094982      4.734578
# 384           NaN             NaN      58.003858      3.366412
# 390           NaN             NaN      53.946520      2.650700
# 394           NaN             NaN      51.117388      0.618817
# 401           NaN             NaN      59.564615      1.807090
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 1            -0.476359          0.044769  ...       10.010993   control
# 7            -5.435259          0.383666  ...       10.051628   control
# 13            2.929284          0.265426  ...       10.052600   control
# 23           -2.146863          0.189495  ...       10.016782   control
# 28            0.004730          0.138613  ...       15.088900   control
# ..                 ...               ...  ...             ...       ...
# 378           0.246666          0.103163  ...       10.626136   control
# 384           3.666362          0.493492  ...       15.041644   control
# 390           4.713791          0.388781  ...       15.108131   control
# 394           0.333950          0.016558  ...       10.001366   control
# 401           1.149085          0.276341  ...       10.032520   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 1          complete     1.6002  81.193034     0.253924     0.202449
# 7          complete     1.5240  45.359237     0.221588     0.181396
# 13         complete     1.6764  61.234970     0.267835     0.211157
# 23         complete     1.6510  54.431084     0.274311     0.215204
# 28         complete     1.6002  45.359237     0.282122     0.219917
# ..              ...        ...        ...          ...          ...
# 378      incomplete     1.3716  40.823313     0.237900     0.192629
# 384        complete     1.6510  65.770894     0.293922     0.227192
# 390        complete     1.3716  22.679619     0.217911     0.178951
# 394      incomplete     1.3970  36.287390     0.293353     0.226805
# 401        complete     1.4224  29.211349     0.242742     0.195361
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 1        20.244878     0.797282      79.728152
# 7        18.139639     0.818619      81.861938
# 13       21.115716     0.788386      78.838558
# 23       21.520393     0.784527      78.452665
# 28       21.991665     0.779509      77.950905
# ..             ...          ...            ...
# 378      19.262906     0.809708      80.970761
# 384      22.719240     0.772967      77.296722
# 390      17.895126     0.821211      82.121092
# 394      22.680549     0.773149      77.314861
# 401      19.536141     0.804811      80.481071
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            WM_SC_ratio   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                   0.03383
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.855
# Time:                        00:02:08   Log-Likelihood:                 110.06
# No. Observations:                  67   AIC:                            -216.1
# Df Residuals:                      65   BIC:                            -211.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8087      0.029     28.322      0.000       0.752       0.866
# age           -0.0004      0.002     -0.184      0.855      -0.005       0.004
# ==============================================================================
# Omnibus:                       79.075   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              668.928
# Skew:                           3.613   Prob(JB):                    5.55e-146
# Kurtosis:                      16.689   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 2    2026-07-09 23:05:31             7.1
# 9    2026-07-09 23:06:28             7.1
# 16   2026-07-09 23:04:36             7.1
# 19   2026-07-09 23:04:35             7.1
# 26   2026-07-09 23:05:14             7.1
# ..                   ...             ...
# 381  2026-07-09 23:05:44             7.1
# 382  2026-07-09 23:05:31             7.1
# 391  2026-07-09 23:06:28             7.1
# 396  2026-07-09 23:05:17             7.1
# 403  2026-07-09 23:05:41             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 2    /Users/samuellestonge/Documents/datasets/phila...            0:12
# 9    /Users/samuellestonge/Documents/datasets/phila...            1:13
# 16   /Users/samuellestonge/Documents/datasets/phila...            1:14
# 19   /Users/samuellestonge/Documents/datasets/phila...            0:14
# 26   /Users/samuellestonge/Documents/datasets/phila...            1:14
# ..                                                 ...             ...
# 381  /Users/samuellestonge/Documents/datasets/phila...            1:12
# 382  /Users/samuellestonge/Documents/datasets/phila...            0:13
# 391  /Users/samuellestonge/Documents/datasets/phila...            1:13
# 396  /Users/samuellestonge/Documents/datasets/phila...            4:14
# 403  /Users/samuellestonge/Documents/datasets/phila...            0:11
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 2             NaN             NaN      60.387836      2.690938
# 9             NaN             NaN      59.135176      3.782576
# 16            NaN             NaN      58.340409      3.786702
# 19            NaN             NaN      52.524212      4.535168
# 26            NaN             NaN      64.076981      5.227640
# ..            ...             ...            ...           ...
# 381           NaN             NaN      59.301421      3.999633
# 382           NaN             NaN      58.627606      3.040722
# 391           NaN             NaN      56.427382      4.473390
# 396           NaN             NaN      54.945862      2.576273
# 403           NaN             NaN      56.654399      4.658251
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 2            -0.632134          0.327167  ...       65.060729   control
# 9            -2.025765          2.122585  ...       65.341217   control
# 16            2.272932          0.733602  ...       70.350267   control
# 19           -2.425807          1.171432  ...       75.204523   control
# 26           -0.612333          0.390950  ...       70.386154   control
# ..                 ...               ...  ...             ...       ...
# 381          -0.142769          0.213787  ...       60.998487   control
# 382           6.190887          1.682551  ...       70.616414   control
# 391           4.069984          1.524070  ...       66.101802   control
# 396           0.083071          0.203574  ...       55.256581   control
# 403           2.386701          0.643941  ...       60.223873   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 2          complete     1.6002  81.193034     0.251579     0.200998
# 9          complete     1.5240  45.359237     0.214366     0.176523
# 16         complete     1.6764  61.234970     0.258429     0.205366
# 19         complete     1.6510  54.431084     0.253266     0.202095
# 26         complete     1.6002  45.359237     0.239183     0.193029
# ..              ...        ...        ...          ...          ...
# 381      incomplete     1.3716  40.823313     0.247829     0.198666
# 382        complete     1.6510  65.770894     0.259368     0.205921
# 391        complete     1.3716  22.679619     0.216346     0.177879
# 396      incomplete     1.3970  36.287390     0.263148     0.208328
# 403        complete     1.4224  29.211349     0.231178     0.187771
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 2        20.099786     0.798946      79.894647
# 9        17.652340     0.823468      82.346781
# 16       20.536586     0.794670      79.466957
# 19       20.209535     0.797956      79.795631
# 26       19.302931     0.807034      80.703438
# ..             ...          ...            ...
# 381      19.866588     0.801625      80.162512
# 382      20.592091     0.793933      79.393283
# 391      17.787914     0.822197      82.219670
# 396      20.832821     0.791677      79.167699
# 403      18.777087     0.812236      81.223628
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            WM_SC_ratio   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.2001
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.656
# Time:                        00:02:08   Log-Likelihood:                 174.58
# No. Observations:                  67   AIC:                            -345.2
# Df Residuals:                      65   BIC:                            -340.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8009      0.011     73.479      0.000       0.779       0.823
# age            0.0004      0.001      0.447      0.656      -0.001       0.002
# ==============================================================================
# Omnibus:                       18.784   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.559
# Skew:                           1.168   Prob(JB):                     4.65e-06
# Kurtosis:                       4.827   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Plot GM / WM CSA ratio vs Age

# %%
plot_ratio(df_GM_WM_SC, 'GM', 'WM', 0.1, 0.35)
# Out:
#             Timestamp_WM  SCT Version_WM  \
# 5    2026-07-09 23:05:21             7.1
# 11   2026-07-09 23:06:17             7.1
# 17   2026-07-09 23:04:26             7.1
# 18   2026-07-09 23:04:26             7.1
# 24   2026-07-09 23:05:04             7.1
# ..                   ...             ...
# 380  2026-07-09 23:05:34             7.1
# 383  2026-07-09 23:05:22             7.1
# 388  2026-07-09 23:06:17             7.1
# 399  2026-07-09 23:05:07             7.1
# 405  2026-07-09 23:05:31             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 5    /Users/samuellestonge/Documents/datasets/phila...           10:12
# 11   /Users/samuellestonge/Documents/datasets/phila...           11:13
# 17   /Users/samuellestonge/Documents/datasets/phila...           12:14
# 18   /Users/samuellestonge/Documents/datasets/phila...           11:14
# 24   /Users/samuellestonge/Documents/datasets/phila...           13:14
# ..                                                 ...             ...
# 380  /Users/samuellestonge/Documents/datasets/phila...           10:12
# 383  /Users/samuellestonge/Documents/datasets/phila...           11:13
# 388  /Users/samuellestonge/Documents/datasets/phila...            9:13
# 399  /Users/samuellestonge/Documents/datasets/phila...           12:14
# 405  /Users/samuellestonge/Documents/datasets/phila...            8:11
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 5             NaN             NaN      59.523449      0.960178
# 11            NaN             NaN      60.567087      2.208685
# 17            NaN             NaN      54.537264      4.027795
# 18            NaN             NaN      51.048281      2.750562
# 24            NaN             NaN      63.254317      3.036252
# ..            ...             ...            ...           ...
# 380           NaN             NaN      57.854535      1.788361
# 383           NaN             NaN      59.478389      0.463983
# 388           NaN             NaN      60.308896      3.504808
# 399           NaN             NaN      56.526345      0.742415
# 405           NaN             NaN      51.122661      1.031887
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 5            -1.166573          0.179585  ...       15.035664   control
# 11            0.574448          0.306361  ...       15.123789   control
# 17            3.277571          0.480251  ...       15.206685   control
# 18           -4.152304          0.787842  ...       20.148369   control
# 24           -1.037004          0.005484  ...       10.180364   control
# ..                 ...               ...  ...             ...       ...
# 380          -0.125454          0.103576  ...       15.148168   control
# 383           8.207483          0.182700  ...       15.280265   control
# 388           2.505784          1.341970  ...       25.585408   control
# 399          -0.194259          0.074184  ...       15.147575   control
# 405           2.711901          0.222513  ...       20.124046   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 5          complete     1.6002  81.193034     0.208113     0.172261
# 11         complete     1.5240  45.359237     0.211436     0.174497
# 17         complete     1.6764  61.234970     0.216251     0.177873
# 18         complete     1.6510  54.431084     0.223945     0.183026
# 24         complete     1.6002  45.359237     0.179903     0.152713
# ..              ...        ...        ...          ...          ...
# 380      incomplete     1.3716  40.823313     0.215225     0.177128
# 383        complete     1.6510  65.770894     0.208383     0.172371
# 388        complete     1.3716  22.679619     0.205149     0.170249
# 399      incomplete     1.3970  36.287390     0.222472     0.182038
# 405        complete     1.4224  29.211349     0.208755     0.172682
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 5        17.226126     0.827730      82.772986
# 11       17.449698     0.825295      82.529534
# 17       17.787274     0.822528      82.252798
# 18       18.302606     0.817280      81.727999
# 24       15.271336     0.848863      84.886347
# ..             ...          ...            ...
# 380      17.712811     0.822989      82.298913
# 383      17.237083     0.827182      82.718210
# 388      17.024877     0.829879      82.987871
# 399      18.203796     0.818250      81.824954
# 405      17.268172     0.827199      82.719878
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_WM_ratio   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     7.221
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):            0.00914
# Time:                        00:02:08   Log-Likelihood:                 161.00
# No. Observations:                  67   AIC:                            -318.0
# Df Residuals:                      65   BIC:                            -313.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2519      0.013     18.873      0.000       0.225       0.279
# age           -0.0027      0.001     -2.687      0.009      -0.005      -0.001
# ==============================================================================
# Omnibus:                       15.377   Durbin-Watson:                   1.599
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.322
# Skew:                           1.017   Prob(JB):                     0.000105
# Kurtosis:                       4.557   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 4    2026-07-09 23:05:23             7.1
# 10   2026-07-09 23:06:19             7.1
# 15   2026-07-09 23:04:28             7.1
# 21   2026-07-09 23:04:28             7.1
# 25   2026-07-09 23:05:06             7.1
# ..                   ...             ...
# 376  2026-07-09 23:05:36             7.1
# 386  2026-07-09 23:05:23             7.1
# 393  2026-07-09 23:06:19             7.1
# 397  2026-07-09 23:05:09             7.1
# 404  2026-07-09 23:05:33             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 4    /Users/samuellestonge/Documents/datasets/phila...             8:9
# 10   /Users/samuellestonge/Documents/datasets/phila...            8:10
# 15   /Users/samuellestonge/Documents/datasets/phila...            9:11
# 21   /Users/samuellestonge/Documents/datasets/phila...            8:10
# 25   /Users/samuellestonge/Documents/datasets/phila...           10:12
# ..                                                 ...             ...
# 376  /Users/samuellestonge/Documents/datasets/phila...             8:9
# 386  /Users/samuellestonge/Documents/datasets/phila...            8:10
# 393  /Users/samuellestonge/Documents/datasets/phila...               8
# 397  /Users/samuellestonge/Documents/datasets/phila...           10:11
# 404  /Users/samuellestonge/Documents/datasets/phila...             6:7
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 4             NaN             NaN      60.227878      0.260861
# 10            NaN             NaN      54.854543      1.305650
# 15            NaN             NaN      57.252902      3.654014
# 21            NaN             NaN      47.438782      1.835056
# 25            NaN             NaN      61.268959      1.965815
# ..            ...             ...            ...           ...
# 376           NaN             NaN      55.939351      2.319029
# 386           NaN             NaN      54.822356      1.491608
# 393           NaN             NaN      55.671147      0.000000
# 397           NaN             NaN      55.420332      2.029799
# 404           NaN             NaN      56.028857      0.466785
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 4            -0.702973          0.073091  ...       10.003936   control
# 10           -0.721812          0.399416  ...       15.087004   control
# 15            1.951061          0.243185  ...       15.046978   control
# 21           -2.211707          0.318964  ...       15.019901   control
# 25           -0.963584          0.037268  ...       15.057403   control
# ..                 ...               ...  ...             ...       ...
# 376          -0.339409          0.019438  ...       10.058584   control
# 386           7.383401          0.266287  ...       15.161974   control
# 393           4.782581          0.000000  ...        5.126682   control
# 397           0.013025          0.036930  ...       10.061209   control
# 404           2.966345          0.026762  ...       10.039870   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 4          complete     1.6002  81.193034     0.250947     0.200596
# 10         complete     1.5240  45.359237     0.262738     0.208065
# 15         complete     1.6764  61.234970     0.253907     0.202502
# 21         complete     1.6510  54.431084     0.224628     0.183437
# 25         complete     1.6002  45.359237     0.215802     0.177556
# ..              ...        ...        ...          ...          ...
# 376      incomplete     1.3716  40.823313     0.241891     0.194745
# 386        complete     1.6510  65.770894     0.244641     0.196482
# 393        complete     1.3716  22.679619     0.157664     0.136202
# 397      incomplete     1.3970  36.287390     0.266596     0.210485
# 404        complete     1.4224  29.211349     0.226626     0.184757
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 4        20.059550     0.799355      79.935485
# 10       20.806467     0.791908      79.190819
# 15       20.250201     0.797543      79.754269
# 21       18.343720     0.816626      81.662647
# 25       17.755618     0.822772      82.277217
# ..             ...          ...            ...
# 376      19.474506     0.805093      80.509266
# 386      19.648203     0.803144      80.314351
# 393      13.620155     0.863871      86.387068
# 397      21.048478     0.789526      78.952594
# 404      18.475715     0.815250      81.525037
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_WM_ratio   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     3.480
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):             0.0666
# Time:                        00:02:08   Log-Likelihood:                 136.70
# No. Observations:                  67   AIC:                            -269.4
# Df Residuals:                      65   BIC:                            -265.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2776      0.019     14.467      0.000       0.239       0.316
# age           -0.0027      0.001     -1.865      0.067      -0.006       0.000
# ==============================================================================
# Omnibus:                        3.072   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.215   Jarque-Bera (JB):                2.863
# Skew:                           0.036   Prob(JB):                        0.239
# Kurtosis:                       4.010   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 3    2026-07-09 23:05:25             7.1
# 8    2026-07-09 23:06:21             7.1
# 14   2026-07-09 23:04:30             7.1
# 20   2026-07-09 23:04:29             7.1
# 27   2026-07-09 23:05:08             7.1
# ..                   ...             ...
# 377  2026-07-09 23:05:38             7.1
# 387  2026-07-09 23:05:25             7.1
# 392  2026-07-09 23:06:22             7.1
# 398  2026-07-09 23:05:11             7.1
# 402  2026-07-09 23:05:35             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 3    /Users/samuellestonge/Documents/datasets/phila...             5:7
# 8    /Users/samuellestonge/Documents/datasets/phila...             6:7
# 14   /Users/samuellestonge/Documents/datasets/phila...             6:8
# 20   /Users/samuellestonge/Documents/datasets/phila...             5:7
# 27   /Users/samuellestonge/Documents/datasets/phila...             7:9
# ..                                                 ...             ...
# 377  /Users/samuellestonge/Documents/datasets/phila...             5:7
# 387  /Users/samuellestonge/Documents/datasets/phila...             5:7
# 392  /Users/samuellestonge/Documents/datasets/phila...             6:7
# 398  /Users/samuellestonge/Documents/datasets/phila...             8:9
# 402  /Users/samuellestonge/Documents/datasets/phila...             3:5
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 3             NaN             NaN      58.827611      1.698180
# 8             NaN             NaN      55.804004      0.768079
# 14            NaN             NaN      58.387201      0.968191
# 20            NaN             NaN      53.728778      5.204125
# 27            NaN             NaN      66.298396      1.850538
# ..            ...             ...            ...           ...
# 377           NaN             NaN      60.104501      3.799112
# 387           NaN             NaN      60.290770      2.124967
# 392           NaN             NaN      53.860084      4.681662
# 398           NaN             NaN      56.940832      0.339244
# 402           NaN             NaN      59.579088      1.441259
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 3            -0.435720          0.059625  ...       15.001372   control
# 8            -2.054715          0.291721  ...       10.035984   control
# 14            1.499857          0.023234  ...       15.008673   control
# 20           -1.449031          0.099133  ...       15.005932   control
# 27           -0.765064          0.071011  ...       15.007817   control
# ..                 ...               ...  ...             ...       ...
# 377          -0.319838          0.040607  ...       15.015595   control
# 387           6.250311          0.350830  ...       15.092876   control
# 392           5.288535          0.116256  ...       10.191633   control
# 398           0.147164          0.030139  ...       10.033874   control
# 402           2.555740          0.214142  ...       15.022596   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 3          complete     1.6002  81.193034     0.269127     0.212057
# 8          complete     1.5240  45.359237     0.218759     0.179511
# 14         complete     1.6764  61.234970     0.283850     0.221104
# 20         complete     1.6510  54.431084     0.266717     0.210567
# 27         complete     1.6002  45.359237     0.254929     0.203126
# ..              ...        ...        ...          ...          ...
# 377      incomplete     1.3716  40.823313     0.267256     0.210893
# 387        complete     1.6510  65.770894     0.280182     0.218829
# 392        complete     1.3716  22.679619     0.232317     0.188483
# 398      incomplete     1.3970  36.287390     0.268715     0.211763
# 402        complete     1.4224  29.211349     0.254167     0.202664
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 3        21.205655     0.787943      78.794290
# 8        17.951094     0.820590      82.058954
# 14       22.110414     0.778946      77.894605
# 20       21.056667     0.789476      78.947593
# 27       20.312590     0.796796      79.679554
# ..             ...          ...            ...
# 377      21.089251     0.789103      78.910280
# 387      21.882937     0.781026      78.102554
# 392      18.848335     0.811320      81.131984
# 398      21.176301     0.788059      78.805856
# 402      20.266437     0.797367      79.736709
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_WM_ratio   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.4176
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.520
# Time:                        00:02:08   Log-Likelihood:                 144.74
# No. Observations:                  67   AIC:                            -285.5
# Df Residuals:                      65   BIC:                            -281.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2754      0.017     16.182      0.000       0.241       0.309
# age           -0.0008      0.001     -0.646      0.520      -0.003       0.002
# ==============================================================================
# Omnibus:                        1.296   Durbin-Watson:                   2.588
# Prob(Omnibus):                  0.523   Jarque-Bera (JB):                0.714
# Skew:                          -0.211   Prob(JB):                        0.700
# Kurtosis:                       3.278   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 0    2026-07-09 23:05:27             7.1
# 6    2026-07-09 23:06:23             7.1
# 12   2026-07-09 23:04:32             7.1
# 22   2026-07-09 23:04:31             7.1
# 29   2026-07-09 23:05:10             7.1
# ..                   ...             ...
# 379  2026-07-09 23:05:40             7.1
# 385  2026-07-09 23:05:27             7.1
# 389  2026-07-09 23:06:24             7.1
# 395  2026-07-09 23:05:13             7.1
# 400  2026-07-09 23:05:37             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 0    /Users/samuellestonge/Documents/datasets/phila...             2:4
# 6    /Users/samuellestonge/Documents/datasets/phila...             3:5
# 12   /Users/samuellestonge/Documents/datasets/phila...             3:5
# 22   /Users/samuellestonge/Documents/datasets/phila...             2:4
# 29   /Users/samuellestonge/Documents/datasets/phila...             4:6
# ..                                                 ...             ...
# 379  /Users/samuellestonge/Documents/datasets/phila...             3:4
# 385  /Users/samuellestonge/Documents/datasets/phila...             3:4
# 389  /Users/samuellestonge/Documents/datasets/phila...             4:5
# 395  /Users/samuellestonge/Documents/datasets/phila...             6:7
# 400  /Users/samuellestonge/Documents/datasets/phila...               2
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 0             NaN             NaN      61.300003      4.364803
# 6             NaN             NaN      60.667879      1.829342
# 12            NaN             NaN      61.028212      2.451873
# 22            NaN             NaN      55.533542      0.952749
# 29            NaN             NaN      69.685819      3.818387
# ..            ...             ...            ...           ...
# 379           NaN             NaN      63.835640      2.393353
# 385           NaN             NaN      61.500179      1.224447
# 389           NaN             NaN      53.390303      1.976926
# 395           NaN             NaN      53.934173      2.725247
# 400           NaN             NaN      65.437941      0.000000
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 0            -0.350735          0.014703  ...       15.008764   control
# 6            -3.637636          0.552403  ...       15.042813   control
# 12            1.925671          0.236313  ...       15.035331   control
# 22           -1.500651          0.126713  ...       15.013539   control
# 29           -0.442299          0.104806  ...       15.051669   control
# ..                 ...               ...  ...             ...       ...
# 379          -0.095931          0.068135  ...       10.150004   control
# 385           5.074871          0.258342  ...       10.039656   control
# 389           5.439926          0.040531  ...       10.089948   control
# 395           0.254139          0.023348  ...       10.012557   control
# 400           1.894732          0.000000  ...        5.004841   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 0          complete     1.6002  81.193034     0.275756     0.216149
# 6          complete     1.5240  45.359237     0.165746     0.142198
# 12         complete     1.6764  61.234970     0.269716     0.212429
# 22         complete     1.6510  54.431084     0.286308     0.222575
# 29         complete     1.6002  45.359237     0.243908     0.196017
# ..              ...        ...        ...          ...          ...
# 379      incomplete     1.3716  40.823313     0.279110     0.218094
# 385        complete     1.6510  65.770894     0.273532     0.214809
# 389        complete     1.3716  22.679619     0.260078     0.206415
# 395      incomplete     1.3970  36.287390     0.289046     0.224192
# 400        complete     1.4224  29.211349     0.225196     0.183809
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 0        21.614861     0.783840      78.384000
# 6        14.219818     0.857929      85.792912
# 12       21.242868     0.787602      78.760237
# 22       22.257463     0.777396      77.739619
# 29       19.601689     0.803652      80.365167
# ..             ...          ...            ...
# 379      21.809417     0.781393      78.139263
# 385      21.480886     0.785316      78.531618
# 389      20.641472     0.793666      79.366597
# 395      22.419152     0.775627      77.562680
# 400      18.380855     0.816216      81.621590
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_WM_ratio   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     3.025
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):             0.0867
# Time:                        00:02:08   Log-Likelihood:                 146.08
# No. Observations:                  67   AIC:                            -288.2
# Df Residuals:                      65   BIC:                            -283.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2941      0.017     17.636      0.000       0.261       0.327
# age           -0.0022      0.001     -1.739      0.087      -0.005       0.000
# ==============================================================================
# Omnibus:                        9.402   Durbin-Watson:                   2.325
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               19.760
# Skew:                          -0.255   Prob(JB):                     5.12e-05
# Kurtosis:                       5.611   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 1    2026-07-09 23:05:29             7.1
# 7    2026-07-09 23:06:26             7.1
# 13   2026-07-09 23:04:34             7.1
# 23   2026-07-09 23:04:33             7.1
# 28   2026-07-09 23:05:12             7.1
# ..                   ...             ...
# 378  2026-07-09 23:05:42             7.1
# 384  2026-07-09 23:05:29             7.1
# 390  2026-07-09 23:06:26             7.1
# 394  2026-07-09 23:05:15             7.1
# 401  2026-07-09 23:05:39             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 1    /Users/samuellestonge/Documents/datasets/phila...             0:1
# 7    /Users/samuellestonge/Documents/datasets/phila...             1:2
# 13   /Users/samuellestonge/Documents/datasets/phila...             1:2
# 23   /Users/samuellestonge/Documents/datasets/phila...             0:1
# 28   /Users/samuellestonge/Documents/datasets/phila...             1:3
# ..                                                 ...             ...
# 378  /Users/samuellestonge/Documents/datasets/phila...             1:2
# 384  /Users/samuellestonge/Documents/datasets/phila...             0:2
# 390  /Users/samuellestonge/Documents/datasets/phila...             1:3
# 394  /Users/samuellestonge/Documents/datasets/phila...             4:5
# 401  /Users/samuellestonge/Documents/datasets/phila...             0:1
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 1             NaN             NaN      62.816458      0.877176
# 7             NaN             NaN      64.440374      2.046984
# 13            NaN             NaN      61.574490      0.904916
# 23            NaN             NaN      56.783374      3.878101
# 28            NaN             NaN      59.603193      5.896786
# ..            ...             ...            ...           ...
# 378           NaN             NaN      59.094982      4.734578
# 384           NaN             NaN      58.003858      3.366412
# 390           NaN             NaN      53.946520      2.650700
# 394           NaN             NaN      51.117388      0.618817
# 401           NaN             NaN      59.564615      1.807090
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 1            -0.476359          0.044769  ...       10.010993   control
# 7            -5.435259          0.383666  ...       10.051628   control
# 13            2.929284          0.265426  ...       10.052600   control
# 23           -2.146863          0.189495  ...       10.016782   control
# 28            0.004730          0.138613  ...       15.088900   control
# ..                 ...               ...  ...             ...       ...
# 378           0.246666          0.103163  ...       10.626136   control
# 384           3.666362          0.493492  ...       15.041644   control
# 390           4.713791          0.388781  ...       15.108131   control
# 394           0.333950          0.016558  ...       10.001366   control
# 401           1.149085          0.276341  ...       10.032520   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 1          complete     1.6002  81.193034     0.253924     0.202449
# 7          complete     1.5240  45.359237     0.221588     0.181396
# 13         complete     1.6764  61.234970     0.267835     0.211157
# 23         complete     1.6510  54.431084     0.274311     0.215204
# 28         complete     1.6002  45.359237     0.282122     0.219917
# ..              ...        ...        ...          ...          ...
# 378      incomplete     1.3716  40.823313     0.237900     0.192629
# 384        complete     1.6510  65.770894     0.293922     0.227192
# 390        complete     1.3716  22.679619     0.217911     0.178951
# 394      incomplete     1.3970  36.287390     0.293353     0.226805
# 401        complete     1.4224  29.211349     0.242742     0.195361
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 1        20.244878     0.797282      79.728152
# 7        18.139639     0.818619      81.861938
# 13       21.115716     0.788386      78.838558
# 23       21.520393     0.784527      78.452665
# 28       21.991665     0.779509      77.950905
# ..             ...          ...            ...
# 378      19.262906     0.809708      80.970761
# 384      22.719240     0.772967      77.296722
# 390      17.895126     0.821211      82.121092
# 394      22.680549     0.773149      77.314861
# 401      19.536141     0.804811      80.481071
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_WM_ratio   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.5869
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.446
# Time:                        00:02:08   Log-Likelihood:                 141.15
# No. Observations:                  67   AIC:                            -278.3
# Df Residuals:                      65   BIC:                            -273.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2440      0.018     13.592      0.000       0.208       0.280
# age            0.0010      0.001      0.766      0.446      -0.002       0.004
# ==============================================================================
# Omnibus:                        2.544   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.280   Jarque-Bera (JB):                1.747
# Skew:                          -0.286   Prob(JB):                        0.418
# Kurtosis:                       3.547   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#             Timestamp_WM  SCT Version_WM  \
# 2    2026-07-09 23:05:31             7.1
# 9    2026-07-09 23:06:28             7.1
# 16   2026-07-09 23:04:36             7.1
# 19   2026-07-09 23:04:35             7.1
# 26   2026-07-09 23:05:14             7.1
# ..                   ...             ...
# 381  2026-07-09 23:05:44             7.1
# 382  2026-07-09 23:05:31             7.1
# 391  2026-07-09 23:06:28             7.1
# 396  2026-07-09 23:05:17             7.1
# 403  2026-07-09 23:05:41             7.1
#
#                                            Filename_WM Slice (I->S)_WM  \
# 2    /Users/samuellestonge/Documents/datasets/phila...            0:12
# 9    /Users/samuellestonge/Documents/datasets/phila...            1:13
# 16   /Users/samuellestonge/Documents/datasets/phila...            1:14
# 19   /Users/samuellestonge/Documents/datasets/phila...            0:14
# 26   /Users/samuellestonge/Documents/datasets/phila...            1:14
# ..                                                 ...             ...
# 381  /Users/samuellestonge/Documents/datasets/phila...            1:12
# 382  /Users/samuellestonge/Documents/datasets/phila...            0:13
# 391  /Users/samuellestonge/Documents/datasets/phila...            1:13
# 396  /Users/samuellestonge/Documents/datasets/phila...            4:14
# 403  /Users/samuellestonge/Documents/datasets/phila...            0:11
#
#      VertLevel_WM  DistancePMJ_WM  MEAN(area)_WM  STD(area)_WM  \
# 2             NaN             NaN      60.387836      2.690938
# 9             NaN             NaN      59.135176      3.782576
# 16            NaN             NaN      58.340409      3.786702
# 19            NaN             NaN      52.524212      4.535168
# 26            NaN             NaN      64.076981      5.227640
# ..            ...             ...            ...           ...
# 381           NaN             NaN      59.301421      3.999633
# 382           NaN             NaN      58.627606      3.040722
# 391           NaN             NaN      56.427382      4.473390
# 396           NaN             NaN      54.945862      2.576273
# 403           NaN             NaN      56.654399      4.658251
#
#      MEAN(angle_AP)_WM  STD(angle_AP)_WM  ...  SUM(length)_SC  group_SC  \
# 2            -0.632134          0.327167  ...       65.060729   control
# 9            -2.025765          2.122585  ...       65.341217   control
# 16            2.272932          0.733602  ...       70.350267   control
# 19           -2.425807          1.171432  ...       75.204523   control
# 26           -0.612333          0.390950  ...       70.386154   control
# ..                 ...               ...  ...             ...       ...
# 381          -0.142769          0.213787  ...       60.998487   control
# 382           6.190887          1.682551  ...       70.616414   control
# 391           4.069984          1.524070  ...       66.101802   control
# 396           0.083071          0.203574  ...       55.256581   control
# 403           2.386701          0.643941  ...       60.223873   control
#
#      scan_series_SC  height_SC  weight_SC  GM_WM_ratio  GM_SC_ratio  \
# 2          complete     1.6002  81.193034     0.251579     0.200998
# 9          complete     1.5240  45.359237     0.214366     0.176523
# 16         complete     1.6764  61.234970     0.258429     0.205366
# 19         complete     1.6510  54.431084     0.253266     0.202095
# 26         complete     1.6002  45.359237     0.239183     0.193029
# ..              ...        ...        ...          ...          ...
# 381      incomplete     1.3716  40.823313     0.247829     0.198666
# 382        complete     1.6510  65.770894     0.259368     0.205921
# 391        complete     1.3716  22.679619     0.216346     0.177879
# 396      incomplete     1.3970  36.287390     0.263148     0.208328
# 403        complete     1.4224  29.211349     0.231178     0.187771
#
#      GM_percentage  WM_SC_ratio  WM_percentage
# 2        20.099786     0.798946      79.894647
# 9        17.652340     0.823468      82.346781
# 16       20.536586     0.794670      79.466957
# 19       20.209535     0.797956      79.795631
# 26       19.302931     0.807034      80.703438
# ..             ...          ...            ...
# 381      19.866588     0.801625      80.162512
# 382      20.592091     0.793933      79.393283
# 391      17.787914     0.822197      82.219670
# 396      20.832821     0.791677      79.167699
# 403      18.777087     0.812236      81.223628
#
# [67 rows x 90 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            GM_WM_ratio   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     2.778
# Date:                Fri, 10 Jul 2026   Prob (F-statistic):              0.100
# Time:                        00:02:08   Log-Likelihood:                 176.78
# No. Observations:                  67   AIC:                            -349.6
# Df Residuals:                      65   BIC:                            -345.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2657      0.011     25.190      0.000       0.245       0.287
# age           -0.0013      0.001     -1.667      0.100      -0.003       0.000
# ==============================================================================
# Omnibus:                        0.246   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.884   Jarque-Bera (JB):                0.229
# Skew:                           0.130   Prob(JB):                        0.892
# Kurtosis:                       2.882   Cond. No.                         66.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
